# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
import itertools
from sklearn.model_selection import train_test_split
from spacy.tokenizer import Tokenizer
from spacy.lang.en import English
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import LSTM, Embedding
from tensorflow.keras.layers import GRU
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Bidirectional
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
# read preprocessed data
train = pd.read_csv("./train_sampled_reviews.csv")
val = pd.read_csv("./val_sampled_reviews.csv")
test = pd.read_csv("./test_sampled_reviews.csv")

# %%
train_texts = train['Review'].to_numpy()
train_labels = train['Label'].to_numpy()
val_texts = val['Review'].to_numpy()
val_labels = val['Label'].to_numpy()
test_texts = test['Review'].to_numpy()
test_labels = test['Label'].to_numpy()

# %%
def process_tokens(text):
    """
    function to process tokens, replace any unwanted chars
    """
    preprocessed_text = text.lower().replace(",", "").replace(".", "").replace(":", "").replace(")", "").replace("-", "").replace("(", "")
    preprocessed_text = ''.join([i for i in preprocessed_text if not preprocessed_text.isdigit()])
    return preprocessed_text

def preprocessing(data, tokenizer):
    preprocessed_data = []
    for sentence in data:
        sentence = process_tokens(sentence)
        tokens = tokenizer(sentence)
        tlist = []
        for token in tokens:
            tlist.append(str(token))
        preprocessed_data.append(tlist)
    return preprocessed_data

nlp = English()
tokenizer = Tokenizer(nlp.vocab)
train_data = preprocessing(train_texts, tokenizer)
val_data = preprocessing(val_texts, tokenizer)
test_data = preprocessing(test_texts, tokenizer)

## Creating a vectorizer to vectorize text and create matrix of features
## Bag of words technique
class Vectorizer():
    def __init__(self, max_features):
        self.max_features = max_features
        self.vocab_list = None
        self.token_to_index = None

    def fit(self, dataset):
        word_dict = {}
        for sentence in dataset:
            for token in sentence:
                if token not in word_dict:
                    word_dict[token] = 1
                else:
                    word_dict[token] += 1
        word_dict = dict(sorted(word_dict.items(), key=lambda item: item[1], reverse=True))
        end_to_slice = min(len(word_dict), self.max_features)
        word_dict = dict(itertools.islice(word_dict.items(), end_to_slice))
        self.vocab_list = list(word_dict.keys())
        self.token_to_index = {}
        counter = 0
        for token in self.vocab_list:
            self.token_to_index[token] = counter
            counter += 1


    def transform(self, dataset):
        data_matrix = np.zeros((len(dataset), len(self.vocab_list)))
        for i, sentence in enumerate(dataset):
            for token in sentence:
                if token in self.token_to_index:
                    data_matrix[i, self.token_to_index[token]] += 1
        return data_matrix

## max features - top k words to consider only
max_features = 2000

vectorizer = Vectorizer(max_features=max_features)
vectorizer.fit(train_data)

## Checking if the len of vocab = k
X_train = vectorizer.transform(train_data)
X_val = vectorizer.transform(val_data)
X_test = vectorizer.transform(test_data)

y_train = np.array(train_labels)
y_val = np.array(val_labels)
y_test = np.array(test_labels)

vocab = vectorizer.vocab_list

# %%
y_train = y_train.astype('int')
y_val = y_val.astype('int')
y_test = y_test.astype('int')

y_train = to_categorical(y_train, 2)
y_val = to_categorical(y_val, 2)
y_test = to_categorical(y_test, 2)

X_train = X_train.reshape(-1, 1, X_train.shape[1])
X_val = X_val.reshape(-1, 1, X_val.shape[1])
X_test = X_test.reshape(-1, 1, X_test.shape[1])

y_train = y_train.reshape(-1, 2)
y_val = y_val.reshape(-1, 2)
y_test = y_test.reshape(-1, 2)

print(f'X_train.shape: {X_train.shape}, y_train.shape: {y_train.shape}')
# Out:
# X_train.shape: (24000, 1, 2000), y_train.shape: (24000, 2)

# %%
model = None
model = Sequential()
model.add(Bidirectional(LSTM(64, input_shape=(1, max_features), dropout=0.4, return_sequences=True)))
model.add(GRU(64))
model.add(Dense(2, activation='softmax'))

optimizer = Adam(learning_rate=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer,
              metrics=['accuracy'])

checkpoint_path = '/content/drive/MyDrive/advanced_project/models/bilstm_gru_best_model'
checkpoint = ModelCheckpoint(
    filepath=checkpoint_path,
    save_best_only=True,  # Only save the best model
    monitor='val_accuracy',  # Monitor validation accuracy
    mode='max',  # Save the model when validation accuracy improves
    verbose=1  # Print messages about the saving process
)

model.build(input_shape=(X_train.shape))
print(model.summary())
history = model.fit(X_train, y_train,
          batch_size=256,
          validation_data=(X_val, y_val),
          epochs=20,
          callbacks=[checkpoint])

print(history.history.keys())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirection  (24000, 1, 128)           1057280
#  al)
#
#  gru (GRU)                   (24000, 64)               37248
#
#  dense (Dense)               (24000, 2)                130
#
# =================================================================
# Total params: 1094658 (4.18 MB)
# Trainable params: 1094658 (4.18 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/20
# 94/94 [==============================] - ETA: 0s - loss: 0.4159 - accuracy: 0.8051
# Epoch 1: val_accuracy improved from -inf to 0.88806, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_best_model
# 94/94 [==============================] - 29s 226ms/step - loss: 0.4159 - accuracy: 0.8051 - val_loss: 0.2792 - val_accuracy: 0.8881
# Epoch 2/20
# 94/94 [==============================] - ETA: 0s - loss: 0.3381 - accuracy: 0.8515
# Epoch 2: val_accuracy improved from 0.88806 to 0.89194, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_best_model
# 94/94 [==============================] - 21s 225ms/step - loss: 0.3381 - accuracy: 0.8515 - val_loss: 0.2857 - val_accuracy: 0.8919
# Epoch 3/20
# 93/94 [============================>.] - ETA: 0s - loss: 0.3075 - accuracy: 0.8651
# Epoch 3: val_accuracy improved from 0.89194 to 0.91583, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_best_model
# 94/94 [==============================] - 20s 219ms/step - loss: 0.3072 - accuracy: 0.8653 - val_loss: 0.2101 - val_accuracy: 0.9158
# Epoch 4/20
# 94/94 [==============================] - ETA: 0s - loss: 0.2868 - accuracy: 0.8765
# Epoch 4: val_accuracy improved from 0.91583 to 0.94444, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_best_model
# 94/94 [==============================] - 20s 216ms/step - loss: 0.2868 - accuracy: 0.8765 - val_loss: 0.1635 - val_accuracy: 0.9444
# Epoch 5/20
# 94/94 [==============================] - ETA: 0s - loss: 0.2665 - accuracy: 0.8860
# Epoch 5: val_accuracy improved from 0.94444 to 0.95306, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_best_model
# 94/94 [==============================] - 21s 224ms/step - loss: 0.2665 - accuracy: 0.8860 - val_loss: 0.1423 - val_accuracy: 0.9531
# Epoch 6/20
# 94/94 [==============================] - ETA: 0s - loss: 0.2476 - accuracy: 0.8955
# Epoch 6: val_accuracy improved from 0.95306 to 0.96028, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_best_model
# 94/94 [==============================] - 21s 225ms/step - loss: 0.2476 - accuracy: 0.8955 - val_loss: 0.1192 - val_accuracy: 0.9603
# Epoch 7/20
# 94/94 [==============================] - ETA: 0s - loss: 0.2295 - accuracy: 0.9028
# Epoch 7: val_accuracy improved from 0.96028 to 0.97083, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_best_model
# 94/94 [==============================] - 20s 211ms/step - loss: 0.2295 - accuracy: 0.9028 - val_loss: 0.1026 - val_accuracy: 0.9708
# Epoch 8/20
# 94/94 [==============================] - ETA: 0s - loss: 0.2176 - accuracy: 0.9104
# Epoch 8: val_accuracy improved from 0.97083 to 0.97750, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_best_model
# 94/94 [==============================] - 21s 227ms/step - loss: 0.2176 - accuracy: 0.9104 - val_loss: 0.0834 - val_accuracy: 0.9775
# Epoch 9/20
# 94/94 [==============================] - ETA: 0s - loss: 0.2027 - accuracy: 0.9178
# Epoch 9: val_accuracy improved from 0.97750 to 0.98111, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_best_model
# 94/94 [==============================] - 21s 222ms/step - loss: 0.2027 - accuracy: 0.9178 - val_loss: 0.0644 - val_accuracy: 0.9811
# Epoch 10/20
# 94/94 [==============================] - ETA: 0s - loss: 0.1935 - accuracy: 0.9215
# Epoch 10: val_accuracy improved from 0.98111 to 0.98417, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_best_model
# 94/94 [==============================] - 20s 217ms/step - loss: 0.1935 - accuracy: 0.9215 - val_loss: 0.0603 - val_accuracy: 0.9842
# Epoch 11/20
# 94/94 [==============================] - ETA: 0s - loss: 0.1864 - accuracy: 0.9249
# Epoch 11: val_accuracy improved from 0.98417 to 0.98972, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_best_model
# 94/94 [==============================] - 21s 223ms/step - loss: 0.1864 - accuracy: 0.9249 - val_loss: 0.0521 - val_accuracy: 0.9897
# Epoch 12/20
# 93/94 [============================>.] - ETA: 0s - loss: 0.1738 - accuracy: 0.9309
# Epoch 12: val_accuracy improved from 0.98972 to 0.99083, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_best_model
# 94/94 [==============================] - 21s 229ms/step - loss: 0.1737 - accuracy: 0.9309 - val_loss: 0.0436 - val_accuracy: 0.9908
# Epoch 13/20
# 94/94 [==============================] - ETA: 0s - loss: 0.1674 - accuracy: 0.9331
# Epoch 13: val_accuracy improved from 0.99083 to 0.99278, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_best_model
# 94/94 [==============================] - 20s 212ms/step - loss: 0.1674 - accuracy: 0.9331 - val_loss: 0.0386 - val_accuracy: 0.9928
# Epoch 14/20
# 94/94 [==============================] - ETA: 0s - loss: 0.1633 - accuracy: 0.9352
# Epoch 14: val_accuracy improved from 0.99278 to 0.99472, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_best_model
# 94/94 [==============================] - 23s 245ms/step - loss: 0.1633 - accuracy: 0.9352 - val_loss: 0.0322 - val_accuracy: 0.9947
# Epoch 15/20
# 94/94 [==============================] - ETA: 0s - loss: 0.1526 - accuracy: 0.9386
# Epoch 15: val_accuracy did not improve from 0.99472
# 94/94 [==============================] - 4s 46ms/step - loss: 0.1526 - accuracy: 0.9386 - val_loss: 0.0296 - val_accuracy: 0.9942
# Epoch 16/20
# 93/94 [============================>.] - ETA: 0s - loss: 0.1516 - accuracy: 0.9402
# Epoch 16: val_accuracy improved from 0.99472 to 0.99639, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_best_model
# 94/94 [==============================] - 20s 217ms/step - loss: 0.1514 - accuracy: 0.9405 - val_loss: 0.0263 - val_accuracy: 0.9964
# Epoch 17/20
# 94/94 [==============================] - ETA: 0s - loss: 0.1404 - accuracy: 0.9455
# Epoch 17: val_accuracy improved from 0.99639 to 0.99806, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_best_model
# 94/94 [==============================] - 22s 241ms/step - loss: 0.1404 - accuracy: 0.9455 - val_loss: 0.0294 - val_accuracy: 0.9981
# Epoch 18/20
# 94/94 [==============================] - ETA: 0s - loss: 0.1397 - accuracy: 0.9433
# Epoch 18: val_accuracy did not improve from 0.99806
# 94/94 [==============================] - 6s 66ms/step - loss: 0.1397 - accuracy: 0.9433 - val_loss: 0.0224 - val_accuracy: 0.9975
# Epoch 19/20
# 94/94 [==============================] - ETA: 0s - loss: 0.1374 - accuracy: 0.9467
# Epoch 19: val_accuracy did not improve from 0.99806
# 94/94 [==============================] - 7s 80ms/step - loss: 0.1374 - accuracy: 0.9467 - val_loss: 0.0196 - val_accuracy: 0.9967
# Epoch 20/20
# 94/94 [==============================] - ETA: 0s - loss: 0.1336 - accuracy: 0.9477
# Epoch 20: val_accuracy improved from 0.99806 to 0.99861, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_best_model
# 94/94 [==============================] - 21s 230ms/step - loss: 0.1336 - accuracy: 0.9477 - val_loss: 0.0154 - val_accuracy: 0.9986
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
best_model = load_model(checkpoint_path)
score, acc = best_model.evaluate(X_test, y_test, verbose=0)
print(f'Test loss for BiLSTM-GRU model: {score:.3f}')
print(f'Test accuracy for BiLSTM-GRU model: {acc:.3f}')
# Out:
# Test loss for BiLSTM-GRU model: 0.414
# Test accuracy for BiLSTM-GRU model: 0.857

# %% [markdown]
# ##Testing on Yelp Review Dataset

# %%
yelp_train = pd.read_csv('yelp_train.csv')
yelp_val = pd.read_csv('yelp_val.csv')
yelp_test = pd.read_csv('yelp_test.csv')

yelp_train = yelp_train.drop(['Unnamed: 0'], axis=1)
yelp_val = yelp_val.drop(['Unnamed: 0'], axis=1)
yelp_test = yelp_test.drop(['Unnamed: 0'], axis=1)

yelp_train.head()
# Out:
#    Label                                             Review
# 0      1  i was a feeling a little abandoned in creepy t...
# 1      1  The food & atmosphere at Sushi Rock is awesome...
# 2      0  2.5  stars. Did I come on the wrong day? We ca...
# 3      1  Food here is great, had the chicken schwarma w...
# 4      1  I was really craving some Asian noodles, so af...

# %%
train_labels_y, train_texts_y = yelp_train.values[:,0], yelp_train.values[:,1]
val_labels_y, val_texts_y = yelp_val.values[:,0], yelp_val.values[:,1]
test_labels_y, test_texts_y = yelp_test.values[:,0], yelp_test.values[:,1]

# %%
nlp = English()
tokenizer = Tokenizer(nlp.vocab)

train_data_y = preprocessing(train_texts_y, tokenizer)
val_data_y = preprocessing(val_texts_y, tokenizer)
test_data_y = preprocessing(test_texts_y, tokenizer)

# %%
## max features - top k words to consider only
max_features = 2000

vectorizer_y = Vectorizer(max_features=max_features)
vectorizer_y.fit(train_data_y)

## Checking if the len of vocab = k
X_train_y = vectorizer_y.transform(train_data_y)
X_val_y = vectorizer_y.transform(val_data_y)
X_test_y = vectorizer_y.transform(test_data_y)

y_train_y = np.array(train_labels_y)
y_val_y = np.array(val_labels_y)
y_test_y = np.array(test_labels_y)

vocab_y = vectorizer_y.vocab_list

# %%
y_train_y = y_train_y.astype('int')
y_val_y = y_val_y.astype('int')
y_test_y = y_test_y.astype('int')

y_train_y = to_categorical(y_train_y, 2)
y_val_y = to_categorical(y_val_y, 2)
y_test_y = to_categorical(y_test_y, 2)

X_train_y = X_train_y.reshape(-1, 1, X_train_y.shape[1])
X_val_y = X_val_y.reshape(-1, 1, X_val_y.shape[1])
X_test_y = X_test_y.reshape(-1, 1, X_test_y.shape[1])

y_train_y = y_train_y.reshape(-1, 2)
y_val_y = y_val_y.reshape(-1, 2)
y_test_y = y_test_y.reshape(-1, 2)

print(f'X_train_y.shape: {X_train_y.shape}, y_train_y.shape: {y_train_y.shape}')
# Out:
# X_train_y.shape: (26600, 1, 2000), y_train_y.shape: (26600, 2)

# %%
score_yelp, acc_yelp = best_model.evaluate(X_test_y, y_test_y, verbose=0)
print(f'Test loss for BiLSTM-GRU model on Yelp dataset: {score_yelp:.3f}')
print(f'Test accuracy for BiLSTM-GRU model on Yelp dataset: {acc_yelp:.3f}')
# Out:
# Test loss for BiLSTM-GRU model on Yelp dataset: 1.569
# Test accuracy for BiLSTM-GRU model on Yelp dataset: 0.544

# %%
# finetuning model
model_ft = load_model(checkpoint_path)

optimizer = Adam(learning_rate=0.001)

model_ft.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

ft_checkpoint_path = '/content/drive/MyDrive/advanced_project/models/bilstm_gru_finetuned_best_model'
ft_checkpoint = ModelCheckpoint(
    filepath=ft_checkpoint_path,
    save_best_only=True,
    monitor='val_accuracy',
    mode='max',
    verbose=1
)

history_ft = model_ft.fit(
    X_train_y, y_train_y,
    batch_size=256,
    validation_data=(X_val_y, y_val_y),
    epochs=20,
    callbacks=[ft_checkpoint]
)

# Print history keys
print(history_ft.history.keys())
# Out:
# Epoch 1/20
# 104/104 [==============================] - ETA: 0s - loss: 1.0073 - accuracy: 0.5606
# Epoch 1: val_accuracy improved from -inf to 0.61449, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_finetuned_best_model
# 104/104 [==============================] - 30s 235ms/step - loss: 1.0073 - accuracy: 0.5606 - val_loss: 0.6882 - val_accuracy: 0.6145
# Epoch 2/20
# 104/104 [==============================] - ETA: 0s - loss: 0.6797 - accuracy: 0.6109
# Epoch 2: val_accuracy improved from 0.61449 to 0.64994, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_finetuned_best_model
# 104/104 [==============================] - 20s 192ms/step - loss: 0.6797 - accuracy: 0.6109 - val_loss: 0.6359 - val_accuracy: 0.6499
# Epoch 3/20
# 104/104 [==============================] - ETA: 0s - loss: 0.6361 - accuracy: 0.6492
# Epoch 3: val_accuracy improved from 0.64994 to 0.69240, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_finetuned_best_model
# 104/104 [==============================] - 23s 225ms/step - loss: 0.6361 - accuracy: 0.6492 - val_loss: 0.5945 - val_accuracy: 0.6924
# Epoch 4/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.5981 - accuracy: 0.6862
# Epoch 4: val_accuracy improved from 0.69240 to 0.73522, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_finetuned_best_model
# 104/104 [==============================] - 22s 210ms/step - loss: 0.5975 - accuracy: 0.6869 - val_loss: 0.5396 - val_accuracy: 0.7352
# Epoch 5/20
# 104/104 [==============================] - ETA: 0s - loss: 0.5436 - accuracy: 0.7297
# Epoch 5: val_accuracy improved from 0.73522 to 0.77680, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_finetuned_best_model
# 104/104 [==============================] - 20s 196ms/step - loss: 0.5436 - accuracy: 0.7297 - val_loss: 0.4737 - val_accuracy: 0.7768
# Epoch 6/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.4920 - accuracy: 0.7630
# Epoch 6: val_accuracy improved from 0.77680 to 0.81155, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_finetuned_best_model
# 104/104 [==============================] - 24s 231ms/step - loss: 0.4915 - accuracy: 0.7632 - val_loss: 0.4170 - val_accuracy: 0.8115
# Epoch 7/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.4492 - accuracy: 0.7901
# Epoch 7: val_accuracy improved from 0.81155 to 0.83611, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_finetuned_best_model
# 104/104 [==============================] - 20s 191ms/step - loss: 0.4487 - accuracy: 0.7903 - val_loss: 0.3748 - val_accuracy: 0.8361
# Epoch 8/20
# 104/104 [==============================] - ETA: 0s - loss: 0.4153 - accuracy: 0.8095
# Epoch 8: val_accuracy improved from 0.83611 to 0.85313, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_finetuned_best_model
# 104/104 [==============================] - 24s 229ms/step - loss: 0.4153 - accuracy: 0.8095 - val_loss: 0.3467 - val_accuracy: 0.8531
# Epoch 9/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.3826 - accuracy: 0.8298
# Epoch 9: val_accuracy improved from 0.85313 to 0.86506, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_finetuned_best_model
# 104/104 [==============================] - 21s 207ms/step - loss: 0.3822 - accuracy: 0.8298 - val_loss: 0.3221 - val_accuracy: 0.8651
# Epoch 10/20
# 104/104 [==============================] - ETA: 0s - loss: 0.3620 - accuracy: 0.8388
# Epoch 10: val_accuracy improved from 0.86506 to 0.87314, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_finetuned_best_model
# 104/104 [==============================] - 21s 204ms/step - loss: 0.3620 - accuracy: 0.8388 - val_loss: 0.3057 - val_accuracy: 0.8731
# Epoch 11/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.3455 - accuracy: 0.8481
# Epoch 11: val_accuracy improved from 0.87314 to 0.87471, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_finetuned_best_model
# 104/104 [==============================] - 23s 223ms/step - loss: 0.3451 - accuracy: 0.8484 - val_loss: 0.2935 - val_accuracy: 0.8747
# Epoch 12/20
# 104/104 [==============================] - ETA: 0s - loss: 0.3321 - accuracy: 0.8552
# Epoch 12: val_accuracy improved from 0.87471 to 0.87840, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_finetuned_best_model
# 104/104 [==============================] - 20s 195ms/step - loss: 0.3321 - accuracy: 0.8552 - val_loss: 0.2836 - val_accuracy: 0.8784
# Epoch 13/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.3195 - accuracy: 0.8621
# Epoch 13: val_accuracy improved from 0.87840 to 0.88489, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_finetuned_best_model
# 104/104 [==============================] - 24s 232ms/step - loss: 0.3191 - accuracy: 0.8624 - val_loss: 0.2732 - val_accuracy: 0.8849
# Epoch 14/20
# 104/104 [==============================] - ETA: 0s - loss: 0.3037 - accuracy: 0.8697
# Epoch 14: val_accuracy improved from 0.88489 to 0.88788, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_finetuned_best_model
# 104/104 [==============================] - 21s 199ms/step - loss: 0.3037 - accuracy: 0.8697 - val_loss: 0.2665 - val_accuracy: 0.8879
# Epoch 15/20
# 104/104 [==============================] - ETA: 0s - loss: 0.2989 - accuracy: 0.8724
# Epoch 15: val_accuracy improved from 0.88788 to 0.89156, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_finetuned_best_model
# 104/104 [==============================] - 24s 231ms/step - loss: 0.2989 - accuracy: 0.8724 - val_loss: 0.2594 - val_accuracy: 0.8916
# Epoch 16/20
# 104/104 [==============================] - ETA: 0s - loss: 0.2899 - accuracy: 0.8777
# Epoch 16: val_accuracy improved from 0.89156 to 0.89367, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_finetuned_best_model
# 104/104 [==============================] - 21s 204ms/step - loss: 0.2899 - accuracy: 0.8777 - val_loss: 0.2558 - val_accuracy: 0.8937
# Epoch 17/20
# 104/104 [==============================] - ETA: 0s - loss: 0.2770 - accuracy: 0.8815
# Epoch 17: val_accuracy improved from 0.89367 to 0.89770, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_finetuned_best_model
# 104/104 [==============================] - 21s 202ms/step - loss: 0.2770 - accuracy: 0.8815 - val_loss: 0.2516 - val_accuracy: 0.8977
# Epoch 18/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.2713 - accuracy: 0.8858
# Epoch 18: val_accuracy improved from 0.89770 to 0.89946, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_finetuned_best_model
# 104/104 [==============================] - 23s 223ms/step - loss: 0.2712 - accuracy: 0.8858 - val_loss: 0.2471 - val_accuracy: 0.8995
# Epoch 19/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.2720 - accuracy: 0.8833
# Epoch 19: val_accuracy did not improve from 0.89946
# 104/104 [==============================] - 5s 50ms/step - loss: 0.2724 - accuracy: 0.8831 - val_loss: 0.2442 - val_accuracy: 0.8984
# Epoch 20/20
# 104/104 [==============================] - ETA: 0s - loss: 0.2611 - accuracy: 0.8904
# Epoch 20: val_accuracy improved from 0.89946 to 0.89998, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_finetuned_best_model
# 104/104 [==============================] - 23s 221ms/step - loss: 0.2611 - accuracy: 0.8904 - val_loss: 0.2414 - val_accuracy: 0.9000
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
best_model_ft = load_model(ft_checkpoint_path)
score_ft, acc_ft = best_model_ft.evaluate(X_test_y, y_test_y, verbose=0)
print(f'Test loss for fine-tuned BiLSTM-GRU model on Yelp dataset: {score_ft:.3f}')
print(f'Test accuracy for fine-tuned BiLSTM-GRU model on Yelp dataset: {acc_ft:.3f}')
# Out:
# Test loss for fine-tuned BiLSTM-GRU model on Yelp dataset: 0.244
# Test accuracy for fine-tuned BiLSTM-GRU model on Yelp dataset: 0.898

# %%
# Feature extractor approach
model_fe = load_model(checkpoint_path)

for layer in model_fe.layers[:-1]:
  layer.trainable = False

optimizer = Adam(learning_rate=0.001)

model_fe.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

fe_checkpoint_path = '/content/drive/MyDrive/advanced_project/models/bilstm_gru_fe_best_model'
fe_checkpoint = ModelCheckpoint(
    filepath=fe_checkpoint_path,
    save_best_only=True,
    monitor='val_accuracy',
    mode='max',
    verbose=1
)

print(model_fe.summary())
history_fe = model_fe.fit(
    X_train_y, y_train_y,
    batch_size=256,
    validation_data=(X_val_y, y_val_y),
    epochs=20,
    callbacks=[fe_checkpoint]
)

# Print history keys
print(history_fe.history.keys())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirection  (None, 1, 128)            1057280
#  al)
#
#  gru (GRU)                   (None, 64)                37248
#
#  dense (Dense)               (None, 2)                 130
#
# =================================================================
# Total params: 1094658 (4.18 MB)
# Trainable params: 130 (520.00 Byte)
# Non-trainable params: 1094528 (4.18 MB)
# _________________________________________________________________
# None
# Epoch 1/20
# 102/104 [============================>.] - ETA: 0s - loss: 1.2314 - accuracy: 0.5265
# Epoch 1: val_accuracy improved from -inf to 0.52290, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_fe_best_model
# 104/104 [==============================] - 30s 243ms/step - loss: 1.2239 - accuracy: 0.5272 - val_loss: 0.8675 - val_accuracy: 0.5229
# Epoch 2/20
# 104/104 [==============================] - ETA: 0s - loss: 0.7601 - accuracy: 0.5202
# Epoch 2: val_accuracy did not improve from 0.52290
# 104/104 [==============================] - 3s 30ms/step - loss: 0.7601 - accuracy: 0.5202 - val_loss: 0.7024 - val_accuracy: 0.5215
# Epoch 3/20
# 102/104 [============================>.] - ETA: 0s - loss: 0.7044 - accuracy: 0.5117
# Epoch 3: val_accuracy did not improve from 0.52290
# 104/104 [==============================] - 3s 30ms/step - loss: 0.7043 - accuracy: 0.5120 - val_loss: 0.6953 - val_accuracy: 0.5217
# Epoch 4/20
# 104/104 [==============================] - ETA: 0s - loss: 0.7008 - accuracy: 0.5165
# Epoch 4: val_accuracy improved from 0.52290 to 0.53115, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_fe_best_model
# 104/104 [==============================] - 20s 196ms/step - loss: 0.7008 - accuracy: 0.5165 - val_loss: 0.6920 - val_accuracy: 0.5311
# Epoch 5/20
# 102/104 [============================>.] - ETA: 0s - loss: 0.6962 - accuracy: 0.5261
# Epoch 5: val_accuracy improved from 0.53115 to 0.53974, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_fe_best_model
# 104/104 [==============================] - 19s 187ms/step - loss: 0.6960 - accuracy: 0.5265 - val_loss: 0.6897 - val_accuracy: 0.5397
# Epoch 6/20
# 102/104 [============================>.] - ETA: 0s - loss: 0.6937 - accuracy: 0.5321
# Epoch 6: val_accuracy improved from 0.53974 to 0.54501, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_fe_best_model
# 104/104 [==============================] - 18s 176ms/step - loss: 0.6936 - accuracy: 0.5327 - val_loss: 0.6878 - val_accuracy: 0.5450
# Epoch 7/20
# 102/104 [============================>.] - ETA: 0s - loss: 0.6917 - accuracy: 0.5366
# Epoch 7: val_accuracy improved from 0.54501 to 0.54764, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_fe_best_model
# 104/104 [==============================] - 21s 199ms/step - loss: 0.6916 - accuracy: 0.5371 - val_loss: 0.6863 - val_accuracy: 0.5476
# Epoch 8/20
# 104/104 [==============================] - ETA: 0s - loss: 0.6886 - accuracy: 0.5474
# Epoch 8: val_accuracy did not improve from 0.54764
# 104/104 [==============================] - 4s 41ms/step - loss: 0.6886 - accuracy: 0.5474 - val_loss: 0.6857 - val_accuracy: 0.5466
# Epoch 9/20
# 104/104 [==============================] - ETA: 0s - loss: 0.6886 - accuracy: 0.5448
# Epoch 9: val_accuracy improved from 0.54764 to 0.54992, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_fe_best_model
# 104/104 [==============================] - 19s 183ms/step - loss: 0.6886 - accuracy: 0.5448 - val_loss: 0.6842 - val_accuracy: 0.5499
# Epoch 10/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.6858 - accuracy: 0.5539
# Epoch 10: val_accuracy improved from 0.54992 to 0.55396, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_fe_best_model
# 104/104 [==============================] - 20s 191ms/step - loss: 0.6858 - accuracy: 0.5539 - val_loss: 0.6831 - val_accuracy: 0.5540
# Epoch 11/20
# 104/104 [==============================] - ETA: 0s - loss: 0.6858 - accuracy: 0.5532
# Epoch 11: val_accuracy improved from 0.55396 to 0.55782, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_fe_best_model
# 104/104 [==============================] - 18s 173ms/step - loss: 0.6858 - accuracy: 0.5532 - val_loss: 0.6827 - val_accuracy: 0.5578
# Epoch 12/20
# 104/104 [==============================] - ETA: 0s - loss: 0.6849 - accuracy: 0.5584
# Epoch 12: val_accuracy improved from 0.55782 to 0.56413, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_fe_best_model
# 104/104 [==============================] - 21s 207ms/step - loss: 0.6849 - accuracy: 0.5584 - val_loss: 0.6817 - val_accuracy: 0.5641
# Epoch 13/20
# 102/104 [============================>.] - ETA: 0s - loss: 0.6845 - accuracy: 0.5574
# Epoch 13: val_accuracy did not improve from 0.56413
# 104/104 [==============================] - 4s 34ms/step - loss: 0.6846 - accuracy: 0.5573 - val_loss: 0.6813 - val_accuracy: 0.5634
# Epoch 14/20
# 104/104 [==============================] - ETA: 0s - loss: 0.6833 - accuracy: 0.5596
# Epoch 14: val_accuracy improved from 0.56413 to 0.56905, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_fe_best_model
# 104/104 [==============================] - 18s 175ms/step - loss: 0.6833 - accuracy: 0.5596 - val_loss: 0.6805 - val_accuracy: 0.5690
# Epoch 15/20
# 104/104 [==============================] - ETA: 0s - loss: 0.6843 - accuracy: 0.5562
# Epoch 15: val_accuracy improved from 0.56905 to 0.57028, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_fe_best_model
# 104/104 [==============================] - 20s 192ms/step - loss: 0.6843 - accuracy: 0.5562 - val_loss: 0.6800 - val_accuracy: 0.5703
# Epoch 16/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.6818 - accuracy: 0.5669
# Epoch 16: val_accuracy improved from 0.57028 to 0.57080, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_fe_best_model
# 104/104 [==============================] - 20s 190ms/step - loss: 0.6818 - accuracy: 0.5672 - val_loss: 0.6794 - val_accuracy: 0.5708
# Epoch 17/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.6808 - accuracy: 0.5673
# Epoch 17: val_accuracy improved from 0.57080 to 0.57150, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_fe_best_model
# 104/104 [==============================] - 18s 179ms/step - loss: 0.6808 - accuracy: 0.5674 - val_loss: 0.6791 - val_accuracy: 0.5715
# Epoch 18/20
# 104/104 [==============================] - ETA: 0s - loss: 0.6825 - accuracy: 0.5632
# Epoch 18: val_accuracy did not improve from 0.57150
# 104/104 [==============================] - 3s 27ms/step - loss: 0.6825 - accuracy: 0.5632 - val_loss: 0.6802 - val_accuracy: 0.5641
# Epoch 19/20
# 104/104 [==============================] - ETA: 0s - loss: 0.6812 - accuracy: 0.5656
# Epoch 19: val_accuracy did not improve from 0.57150
# 104/104 [==============================] - 3s 29ms/step - loss: 0.6812 - accuracy: 0.5656 - val_loss: 0.6786 - val_accuracy: 0.5697
# Epoch 20/20
# 104/104 [==============================] - ETA: 0s - loss: 0.6822 - accuracy: 0.5630
# Epoch 20: val_accuracy did not improve from 0.57150
# 104/104 [==============================] - 3s 30ms/step - loss: 0.6822 - accuracy: 0.5630 - val_loss: 0.6788 - val_accuracy: 0.5652
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
best_model_fe = load_model(fe_checkpoint_path)
score_fe, acc_fe = best_model_fe.evaluate(X_test_y, y_test_y, verbose=0)
print(f'Test loss for feature extractor BiLSTM-GRU model on Yelp dataset: {score_fe:.3f}')
print(f'Test accuracy for feature extractor BiLSTM-GRU model on Yelp dataset: {acc_fe:.3f}')
# Out:
# Test loss for feature extractor BiLSTM-GRU model on Yelp dataset: 0.677
# Test accuracy for feature extractor BiLSTM-GRU model on Yelp dataset: 0.577
