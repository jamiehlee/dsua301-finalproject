# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
import itertools
from sklearn.model_selection import train_test_split
from spacy.tokenizer import Tokenizer
from spacy.lang.en import English
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import LSTM, Embedding
from tensorflow.keras.layers import GRU
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Bidirectional
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
# read preprocessed data
train = pd.read_csv("./train_sampled_reviews.csv")
val = pd.read_csv("./val_sampled_reviews.csv")
test = pd.read_csv("./test_sampled_reviews.csv")

# %%
train_texts = train['Review'].to_numpy()
train_labels = train['Label'].to_numpy()
val_texts = val['Review'].to_numpy()
val_labels = val['Label'].to_numpy()
test_texts = test['Review'].to_numpy()
test_labels = test['Label'].to_numpy()

# %%
def process_tokens(text):
    """
    function to process tokens, replace any unwanted chars
    """
    preprocessed_text = text.lower().replace(",", "").replace(".", "").replace(":", "").replace(")", "").replace("-", "").replace("(", "")
    preprocessed_text = ''.join([i for i in preprocessed_text if not preprocessed_text.isdigit()])
    return preprocessed_text

def preprocessing(data, tokenizer):
    preprocessed_data = []
    for sentence in data:
        sentence = process_tokens(sentence)
        tokens = tokenizer(sentence)
        tlist = []
        for token in tokens:
            tlist.append(str(token))
        preprocessed_data.append(tlist)
    return preprocessed_data

nlp = English()
tokenizer = Tokenizer(nlp.vocab)
train_data = preprocessing(train_texts, tokenizer)
val_data = preprocessing(val_texts, tokenizer)
test_data = preprocessing(test_texts, tokenizer)

## Creating a vectorizer to vectorize text and create matrix of features
## Bag of words technique
class Vectorizer():
    def __init__(self, max_features):
        self.max_features = max_features
        self.vocab_list = None
        self.token_to_index = None

    def fit(self, dataset):
        word_dict = {}
        for sentence in dataset:
            for token in sentence:
                if token not in word_dict:
                    word_dict[token] = 1
                else:
                    word_dict[token] += 1
        word_dict = dict(sorted(word_dict.items(), key=lambda item: item[1], reverse=True))
        end_to_slice = min(len(word_dict), self.max_features)
        word_dict = dict(itertools.islice(word_dict.items(), end_to_slice))
        self.vocab_list = list(word_dict.keys())
        self.token_to_index = {}
        counter = 0
        for token in self.vocab_list:
            self.token_to_index[token] = counter
            counter += 1


    def transform(self, dataset):
        data_matrix = np.zeros((len(dataset), len(self.vocab_list)))
        for i, sentence in enumerate(dataset):
            for token in sentence:
                if token in self.token_to_index:
                    data_matrix[i, self.token_to_index[token]] += 1
        return data_matrix

## max features - top k words to consider only
max_features = 2000

vectorizer = Vectorizer(max_features=max_features)
vectorizer.fit(train_data)

## Checking if the len of vocab = k
X_train = vectorizer.transform(train_data)
X_val = vectorizer.transform(val_data)
X_test = vectorizer.transform(test_data)

y_train = np.array(train_labels)
y_val = np.array(val_labels)
y_test = np.array(test_labels)

vocab = vectorizer.vocab_list

# %%
y_train = y_train.astype('int')
y_val = y_val.astype('int')
y_test = y_test.astype('int')

y_train = to_categorical(y_train, 2)
y_val = to_categorical(y_val, 2)
y_test = to_categorical(y_test, 2)

X_train = X_train.reshape(-1, 1, X_train.shape[1])
X_val = X_val.reshape(-1, 1, X_val.shape[1])
X_test = X_test.reshape(-1, 1, X_test.shape[1])

y_train = y_train.reshape(-1, 2)
y_val = y_val.reshape(-1, 2)
y_test = y_test.reshape(-1, 2)

print(f'X_train.shape: {X_train.shape}, y_train.shape: {y_train.shape}')
# Out:
# X_train.shape: (24000, 1, 2000), y_train.shape: (24000, 2)

# %%
model = None
model = Sequential()
model.add(Bidirectional(LSTM(64, input_shape=(1, max_features), dropout=0.4, return_sequences=True)))
model.add(GRU(64))
model.add(Dense(2, activation='softmax'))

optimizer = Adam(learning_rate=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer,
              metrics=['accuracy'])

checkpoint_path = '/content/drive/MyDrive/advanced_project/models/bilstm_gru_best_model'
checkpoint = ModelCheckpoint(
    filepath=checkpoint_path,
    save_best_only=True,  # Only save the best model
    monitor='val_accuracy',  # Monitor validation accuracy
    mode='max',  # Save the model when validation accuracy improves
    verbose=1  # Print messages about the saving process
)

model.build(input_shape=(X_train.shape))
print(model.summary())
history = model.fit(X_train, y_train,
          batch_size=256,
          validation_data=(X_val, y_val),
          epochs=20,
          callbacks=[checkpoint])

print(history.history.keys())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirecti  (24000, 1, 128)           1057280
#  onal)
#
#  gru_2 (GRU)                 (24000, 64)               37248
#
#  dense_2 (Dense)             (24000, 2)                130
#
# =================================================================
# Total params: 1094658 (4.18 MB)
# Trainable params: 1094658 (4.18 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/20
# 93/94 [============================>.] - ETA: 0s - loss: 0.4209 - accuracy: 0.8056
# Epoch 1: val_accuracy improved from -inf to 0.88417, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_best_model
# 94/94 [==============================] - 37s 272ms/step - loss: 0.4206 - accuracy: 0.8058 - val_loss: 0.2988 - val_accuracy: 0.8842
# Epoch 2/20
# 94/94 [==============================] - ETA: 0s - loss: 0.3398 - accuracy: 0.8521
# Epoch 2: val_accuracy improved from 0.88417 to 0.90472, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_best_model
# 94/94 [==============================] - 23s 243ms/step - loss: 0.3398 - accuracy: 0.8521 - val_loss: 0.2393 - val_accuracy: 0.9047
# Epoch 3/20
# 93/94 [============================>.] - ETA: 0s - loss: 0.3136 - accuracy: 0.8644
# Epoch 3: val_accuracy improved from 0.90472 to 0.91056, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_best_model
# 94/94 [==============================] - 24s 261ms/step - loss: 0.3134 - accuracy: 0.8645 - val_loss: 0.2265 - val_accuracy: 0.9106
# Epoch 4/20
# 94/94 [==============================] - ETA: 0s - loss: 0.2924 - accuracy: 0.8719
# Epoch 4: val_accuracy improved from 0.91056 to 0.93139, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_best_model
# 94/94 [==============================] - 21s 223ms/step - loss: 0.2924 - accuracy: 0.8719 - val_loss: 0.1885 - val_accuracy: 0.9314
# Epoch 5/20
# 94/94 [==============================] - ETA: 0s - loss: 0.2746 - accuracy: 0.8805
# Epoch 5: val_accuracy improved from 0.93139 to 0.94778, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_best_model
# 94/94 [==============================] - 22s 241ms/step - loss: 0.2746 - accuracy: 0.8805 - val_loss: 0.1703 - val_accuracy: 0.9478
# Epoch 6/20
# 93/94 [============================>.] - ETA: 0s - loss: 0.2486 - accuracy: 0.8926
# Epoch 6: val_accuracy improved from 0.94778 to 0.95444, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_best_model
# 94/94 [==============================] - 24s 261ms/step - loss: 0.2484 - accuracy: 0.8928 - val_loss: 0.1312 - val_accuracy: 0.9544
# Epoch 7/20
# 94/94 [==============================] - ETA: 0s - loss: 0.2320 - accuracy: 0.9013
# Epoch 7: val_accuracy improved from 0.95444 to 0.96194, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_best_model
# 94/94 [==============================] - 31s 332ms/step - loss: 0.2320 - accuracy: 0.9013 - val_loss: 0.1144 - val_accuracy: 0.9619
# Epoch 8/20
# 94/94 [==============================] - ETA: 0s - loss: 0.2168 - accuracy: 0.9086
# Epoch 8: val_accuracy improved from 0.96194 to 0.97361, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_best_model
# 94/94 [==============================] - 30s 317ms/step - loss: 0.2168 - accuracy: 0.9086 - val_loss: 0.0997 - val_accuracy: 0.9736
# Epoch 9/20
# 93/94 [============================>.] - ETA: 0s - loss: 0.2024 - accuracy: 0.9166
# Epoch 9: val_accuracy improved from 0.97361 to 0.98083, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_best_model
# 94/94 [==============================] - 23s 244ms/step - loss: 0.2034 - accuracy: 0.9161 - val_loss: 0.0768 - val_accuracy: 0.9808
# Epoch 10/20
# 94/94 [==============================] - ETA: 0s - loss: 0.1997 - accuracy: 0.9180
# Epoch 10: val_accuracy improved from 0.98083 to 0.98806, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_best_model
# 94/94 [==============================] - 22s 236ms/step - loss: 0.1997 - accuracy: 0.9180 - val_loss: 0.0644 - val_accuracy: 0.9881
# Epoch 11/20
# 93/94 [============================>.] - ETA: 0s - loss: 0.1849 - accuracy: 0.9235
# Epoch 11: val_accuracy did not improve from 0.98806
# 94/94 [==============================] - 5s 52ms/step - loss: 0.1841 - accuracy: 0.9238 - val_loss: 0.0466 - val_accuracy: 0.9878
# Epoch 12/20
# 94/94 [==============================] - ETA: 0s - loss: 0.1730 - accuracy: 0.9292
# Epoch 12: val_accuracy improved from 0.98806 to 0.99000, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_best_model
# 94/94 [==============================] - 27s 290ms/step - loss: 0.1730 - accuracy: 0.9292 - val_loss: 0.0484 - val_accuracy: 0.9900
# Epoch 13/20
# 94/94 [==============================] - ETA: 0s - loss: 0.1660 - accuracy: 0.9325
# Epoch 13: val_accuracy improved from 0.99000 to 0.99194, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_best_model
# 94/94 [==============================] - 22s 240ms/step - loss: 0.1660 - accuracy: 0.9325 - val_loss: 0.0455 - val_accuracy: 0.9919
# Epoch 14/20
# 93/94 [============================>.] - ETA: 0s - loss: 0.1568 - accuracy: 0.9356
# Epoch 14: val_accuracy improved from 0.99194 to 0.99250, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_best_model
# 94/94 [==============================] - 21s 228ms/step - loss: 0.1572 - accuracy: 0.9352 - val_loss: 0.0339 - val_accuracy: 0.9925
# Epoch 15/20
# 93/94 [============================>.] - ETA: 0s - loss: 0.1584 - accuracy: 0.9368
# Epoch 15: val_accuracy improved from 0.99250 to 0.99361, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_best_model
# 94/94 [==============================] - 25s 271ms/step - loss: 0.1585 - accuracy: 0.9367 - val_loss: 0.0291 - val_accuracy: 0.9936
# Epoch 16/20
# 93/94 [============================>.] - ETA: 0s - loss: 0.1547 - accuracy: 0.9379
# Epoch 16: val_accuracy improved from 0.99361 to 0.99389, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_best_model
# 94/94 [==============================] - 23s 243ms/step - loss: 0.1549 - accuracy: 0.9378 - val_loss: 0.0327 - val_accuracy: 0.9939
# Epoch 17/20
# 93/94 [============================>.] - ETA: 0s - loss: 0.1442 - accuracy: 0.9430
# Epoch 17: val_accuracy improved from 0.99389 to 0.99750, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_best_model
# 94/94 [==============================] - 22s 237ms/step - loss: 0.1444 - accuracy: 0.9430 - val_loss: 0.0220 - val_accuracy: 0.9975
# Epoch 18/20
# 94/94 [==============================] - ETA: 0s - loss: 0.1387 - accuracy: 0.9464
# Epoch 18: val_accuracy improved from 0.99750 to 0.99778, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_best_model
# 94/94 [==============================] - 25s 265ms/step - loss: 0.1387 - accuracy: 0.9464 - val_loss: 0.0222 - val_accuracy: 0.9978
# Epoch 19/20
# 93/94 [============================>.] - ETA: 0s - loss: 0.1353 - accuracy: 0.9462
# Epoch 19: val_accuracy did not improve from 0.99778
# 94/94 [==============================] - 5s 57ms/step - loss: 0.1351 - accuracy: 0.9462 - val_loss: 0.0195 - val_accuracy: 0.9967
# Epoch 20/20
# 93/94 [============================>.] - ETA: 0s - loss: 0.1339 - accuracy: 0.9493
# Epoch 20: val_accuracy did not improve from 0.99778
# 94/94 [==============================] - 5s 56ms/step - loss: 0.1338 - accuracy: 0.9495 - val_loss: 0.0190 - val_accuracy: 0.9975
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
best_model = load_model(checkpoint_path)
score, acc = best_model.evaluate(X_test, y_test, verbose=0)
print(f'Test loss for BiLSTM-GRU model: {score:.3f}')
print(f'Test accuracy for BiLSTM-GRU model: {acc:.3f}')
# Out:
# Test loss for BiLSTM-GRU model: 0.393
# Test accuracy for BiLSTM-GRU model: 0.861

# %% [markdown]
# ##Testing on Yelp Review Dataset

# %%
yelp_train = pd.read_csv('yelp_train.csv')
yelp_val = pd.read_csv('yelp_val.csv')
yelp_test = pd.read_csv('yelp_test.csv')

yelp_train = yelp_train.drop(['Unnamed: 0'], axis=1)
yelp_val = yelp_val.drop(['Unnamed: 0'], axis=1)
yelp_test = yelp_test.drop(['Unnamed: 0'], axis=1)

yelp_train.head()
# Out:
#    Label                                             Review
# 0      1  i was a feeling a little abandoned in creepy t...
# 1      1  The food & atmosphere at Sushi Rock is awesome...
# 2      0  2.5  stars. Did I come on the wrong day? We ca...
# 3      1  Food here is great, had the chicken schwarma w...
# 4      1  I was really craving some Asian noodles, so af...

# %%
train_labels_y, train_texts_y = yelp_train.values[:,0], yelp_train.values[:,1]
val_labels_y, val_texts_y = yelp_val.values[:,0], yelp_val.values[:,1]
test_labels_y, test_texts_y = yelp_test.values[:,0], yelp_test.values[:,1]

# %%
nlp = English()
tokenizer = Tokenizer(nlp.vocab)

train_data_y = preprocessing(train_texts_y, tokenizer)
val_data_y = preprocessing(val_texts_y, tokenizer)
test_data_y = preprocessing(test_texts_y, tokenizer)

# %%
## max features - top k words to consider only
max_features = 2000

vectorizer_y = Vectorizer(max_features=max_features)
vectorizer_y.fit(train_data_y)

## Checking if the len of vocab = k
X_train_y = vectorizer_y.transform(train_data_y)
X_val_y = vectorizer_y.transform(val_data_y)
X_test_y = vectorizer_y.transform(test_data_y)

y_train_y = np.array(train_labels_y)
y_val_y = np.array(val_labels_y)
y_test_y = np.array(test_labels_y)

vocab_y = vectorizer_y.vocab_list

# %%
y_train_y = y_train_y.astype('int')
y_val_y = y_val_y.astype('int')
y_test_y = y_test_y.astype('int')

y_train_y = to_categorical(y_train_y, 2)
y_val_y = to_categorical(y_val_y, 2)
y_test_y = to_categorical(y_test_y, 2)

X_train_y = X_train_y.reshape(-1, 1, X_train_y.shape[1])
X_val_y = X_val_y.reshape(-1, 1, X_val_y.shape[1])
X_test_y = X_test_y.reshape(-1, 1, X_test_y.shape[1])

y_train_y = y_train_y.reshape(-1, 2)
y_val_y = y_val_y.reshape(-1, 2)
y_test_y = y_test_y.reshape(-1, 2)

print(f'X_train_y.shape: {X_train_y.shape}, y_train_y.shape: {y_train_y.shape}')
# Out:
# X_train_y.shape: (26600, 1, 2000), y_train_y.shape: (26600, 2)

# %%
score_yelp, acc_yelp = best_model.evaluate(X_test_y, y_test_y, verbose=0)
print(f'Test loss for BiLSTM-GRU model on Yelp dataset: {score_yelp:.3f}')
print(f'Test accuracy for BiLSTM-GRU model on Yelp dataset: {acc_yelp:.3f}')
# Out:
# Test loss for BiLSTM-GRU model on Yelp dataset: 1.625
# Test accuracy for BiLSTM-GRU model on Yelp dataset: 0.525

# %%
# finetuning model
model_ft = load_model(checkpoint_path)

optimizer = Adam(learning_rate=0.001)

model_ft.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

ft_checkpoint_path = '/content/drive/MyDrive/advanced_project/models/bilstm_gru_finetuned_best_model'
ft_checkpoint = ModelCheckpoint(
    filepath=ft_checkpoint_path,
    save_best_only=True,
    monitor='val_accuracy',
    mode='max',
    verbose=1
)

history_ft = model_ft.fit(
    X_train_y, y_train_y,
    batch_size=256,
    validation_data=(X_val_y, y_val_y),
    epochs=20,
    callbacks=[ft_checkpoint]
)

# Print history keys
print(history_ft.history.keys())
# Out:
# Epoch 1/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.9777 - accuracy: 0.5523
# Epoch 1: val_accuracy improved from -inf to 0.60695, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_finetuned_best_model
# 104/104 [==============================] - 31s 229ms/step - loss: 0.9758 - accuracy: 0.5521 - val_loss: 0.6802 - val_accuracy: 0.6069
# Epoch 2/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.6702 - accuracy: 0.6088
# Epoch 2: val_accuracy improved from 0.60695 to 0.65327, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_finetuned_best_model
# 104/104 [==============================] - 28s 269ms/step - loss: 0.6702 - accuracy: 0.6089 - val_loss: 0.6345 - val_accuracy: 0.6533
# Epoch 3/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.6278 - accuracy: 0.6560
# Epoch 3: val_accuracy improved from 0.65327 to 0.69451, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_finetuned_best_model
# 104/104 [==============================] - 23s 221ms/step - loss: 0.6276 - accuracy: 0.6562 - val_loss: 0.5867 - val_accuracy: 0.6945
# Epoch 4/20
# 104/104 [==============================] - ETA: 0s - loss: 0.5763 - accuracy: 0.7022
# Epoch 4: val_accuracy improved from 0.69451 to 0.74697, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_finetuned_best_model
# 104/104 [==============================] - 23s 224ms/step - loss: 0.5763 - accuracy: 0.7022 - val_loss: 0.5145 - val_accuracy: 0.7470
# Epoch 5/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.5134 - accuracy: 0.7452
# Epoch 5: val_accuracy improved from 0.74697 to 0.79716, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_finetuned_best_model
# 104/104 [==============================] - 26s 253ms/step - loss: 0.5128 - accuracy: 0.7457 - val_loss: 0.4366 - val_accuracy: 0.7972
# Epoch 6/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.4537 - accuracy: 0.7871
# Epoch 6: val_accuracy improved from 0.79716 to 0.82681, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_finetuned_best_model
# 104/104 [==============================] - 23s 225ms/step - loss: 0.4535 - accuracy: 0.7872 - val_loss: 0.3865 - val_accuracy: 0.8268
# Epoch 7/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.4189 - accuracy: 0.8065
# Epoch 7: val_accuracy improved from 0.82681 to 0.84383, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_finetuned_best_model
# 104/104 [==============================] - 22s 214ms/step - loss: 0.4189 - accuracy: 0.8063 - val_loss: 0.3538 - val_accuracy: 0.8438
# Epoch 8/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.3864 - accuracy: 0.8250
# Epoch 8: val_accuracy improved from 0.84383 to 0.85261, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_finetuned_best_model
# 104/104 [==============================] - 23s 220ms/step - loss: 0.3865 - accuracy: 0.8249 - val_loss: 0.3314 - val_accuracy: 0.8526
# Epoch 9/20
# 104/104 [==============================] - ETA: 0s - loss: 0.3624 - accuracy: 0.8390
# Epoch 9: val_accuracy improved from 0.85261 to 0.86155, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_finetuned_best_model
# 104/104 [==============================] - 27s 257ms/step - loss: 0.3624 - accuracy: 0.8390 - val_loss: 0.3147 - val_accuracy: 0.8616
# Epoch 10/20
# 104/104 [==============================] - ETA: 0s - loss: 0.3463 - accuracy: 0.8493
# Epoch 10: val_accuracy improved from 0.86155 to 0.86752, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_finetuned_best_model
# 104/104 [==============================] - 23s 224ms/step - loss: 0.3463 - accuracy: 0.8493 - val_loss: 0.3028 - val_accuracy: 0.8675
# Epoch 11/20
# 104/104 [==============================] - ETA: 0s - loss: 0.3256 - accuracy: 0.8597
# Epoch 11: val_accuracy improved from 0.86752 to 0.87471, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_finetuned_best_model
# 104/104 [==============================] - 22s 217ms/step - loss: 0.3256 - accuracy: 0.8597 - val_loss: 0.2929 - val_accuracy: 0.8747
# Epoch 12/20
# 104/104 [==============================] - ETA: 0s - loss: 0.3129 - accuracy: 0.8629
# Epoch 12: val_accuracy improved from 0.87471 to 0.87787, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_finetuned_best_model
# 104/104 [==============================] - 26s 247ms/step - loss: 0.3129 - accuracy: 0.8629 - val_loss: 0.2832 - val_accuracy: 0.8779
# Epoch 13/20
# 104/104 [==============================] - ETA: 0s - loss: 0.3017 - accuracy: 0.8699
# Epoch 13: val_accuracy improved from 0.87787 to 0.88068, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_finetuned_best_model
# 104/104 [==============================] - 23s 219ms/step - loss: 0.3017 - accuracy: 0.8699 - val_loss: 0.2763 - val_accuracy: 0.8807
# Epoch 14/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.2948 - accuracy: 0.8745
# Epoch 14: val_accuracy improved from 0.88068 to 0.88437, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_finetuned_best_model
# 104/104 [==============================] - 25s 244ms/step - loss: 0.2950 - accuracy: 0.8743 - val_loss: 0.2716 - val_accuracy: 0.8844
# Epoch 15/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.2882 - accuracy: 0.8785
# Epoch 15: val_accuracy improved from 0.88437 to 0.88630, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_finetuned_best_model
# 104/104 [==============================] - 26s 250ms/step - loss: 0.2875 - accuracy: 0.8788 - val_loss: 0.2661 - val_accuracy: 0.8863
# Epoch 16/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.2767 - accuracy: 0.8837
# Epoch 16: val_accuracy improved from 0.88630 to 0.88858, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_finetuned_best_model
# 104/104 [==============================] - 23s 218ms/step - loss: 0.2764 - accuracy: 0.8838 - val_loss: 0.2623 - val_accuracy: 0.8886
# Epoch 17/20
# 104/104 [==============================] - ETA: 0s - loss: 0.2715 - accuracy: 0.8864
# Epoch 17: val_accuracy improved from 0.88858 to 0.89138, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_finetuned_best_model
# 104/104 [==============================] - 23s 219ms/step - loss: 0.2715 - accuracy: 0.8864 - val_loss: 0.2592 - val_accuracy: 0.8914
# Epoch 18/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.2624 - accuracy: 0.8898
# Epoch 18: val_accuracy did not improve from 0.89138
# 104/104 [==============================] - 7s 67ms/step - loss: 0.2626 - accuracy: 0.8896 - val_loss: 0.2572 - val_accuracy: 0.8905
# Epoch 19/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.2586 - accuracy: 0.8914
# Epoch 19: val_accuracy improved from 0.89138 to 0.89156, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_finetuned_best_model
# 104/104 [==============================] - 26s 251ms/step - loss: 0.2588 - accuracy: 0.8914 - val_loss: 0.2546 - val_accuracy: 0.8916
# Epoch 20/20
# 104/104 [==============================] - ETA: 0s - loss: 0.2519 - accuracy: 0.8944
# Epoch 20: val_accuracy improved from 0.89156 to 0.89384, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_finetuned_best_model
# 104/104 [==============================] - 22s 211ms/step - loss: 0.2519 - accuracy: 0.8944 - val_loss: 0.2532 - val_accuracy: 0.8938
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
best_model_ft = load_model(ft_checkpoint_path)
score_ft, acc_ft = best_model_ft.evaluate(X_test_y, y_test_y, verbose=0)
print(f'Test loss for fine-tuned BiLSTM-GRU model on Yelp dataset: {score_ft:.3f}')
print(f'Test accuracy for fine-tuned BiLSTM-GRU model on Yelp dataset: {acc_ft:.3f}')
# Out:
# Test loss for fine-tuned BiLSTM-GRU model on Yelp dataset: 0.248
# Test accuracy for fine-tuned BiLSTM-GRU model on Yelp dataset: 0.897

# %%
# Feature extractor approach
model_fe = load_model(checkpoint_path)

for layer in model_fe.layers[:-1]:
  layer.trainable = False

optimizer = Adam(learning_rate=0.001)

model_fe.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

fe_checkpoint_path = '/content/drive/MyDrive/advanced_project/models/bilstm_gru_fe_best_model'
fe_checkpoint = ModelCheckpoint(
    filepath=fe_checkpoint_path,
    save_best_only=True,
    monitor='val_accuracy',
    mode='max',
    verbose=1
)

print(model_fe.summary())
history_fe = model_fe.fit(
    X_train_y, y_train_y,
    batch_size=256,
    validation_data=(X_val_y, y_val_y),
    epochs=20,
    callbacks=[fe_checkpoint]
)

# Print history keys
print(history_fe.history.keys())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirecti  (None, 1, 128)            1057280
#  onal)
#
#  gru_2 (GRU)                 (None, 64)                37248
#
#  dense_2 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 1094658 (4.18 MB)
# Trainable params: 130 (520.00 Byte)
# Non-trainable params: 1094528 (4.18 MB)
# _________________________________________________________________
# None
# Epoch 1/20
# 104/104 [==============================] - ETA: 0s - loss: 1.1544 - accuracy: 0.5209
# Epoch 1: val_accuracy improved from -inf to 0.51500, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_fe_best_model
# 104/104 [==============================] - 27s 212ms/step - loss: 1.1544 - accuracy: 0.5209 - val_loss: 0.8149 - val_accuracy: 0.5150
# Epoch 2/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.7316 - accuracy: 0.5106
# Epoch 2: val_accuracy did not improve from 0.51500
# 104/104 [==============================] - 3s 30ms/step - loss: 0.7312 - accuracy: 0.5110 - val_loss: 0.7071 - val_accuracy: 0.5089
# Epoch 3/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.7078 - accuracy: 0.5045
# Epoch 3: val_accuracy did not improve from 0.51500
# 104/104 [==============================] - 3s 34ms/step - loss: 0.7081 - accuracy: 0.5039 - val_loss: 0.7027 - val_accuracy: 0.5054
# Epoch 4/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.7037 - accuracy: 0.5047
# Epoch 4: val_accuracy did not improve from 0.51500
# 104/104 [==============================] - 5s 45ms/step - loss: 0.7035 - accuracy: 0.5053 - val_loss: 0.7005 - val_accuracy: 0.5068
# Epoch 5/20
# 104/104 [==============================] - ETA: 0s - loss: 0.7002 - accuracy: 0.5045
# Epoch 5: val_accuracy did not improve from 0.51500
# 104/104 [==============================] - 3s 33ms/step - loss: 0.7002 - accuracy: 0.5045 - val_loss: 0.6973 - val_accuracy: 0.5129
# Epoch 6/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.6972 - accuracy: 0.5129
# Epoch 6: val_accuracy improved from 0.51500 to 0.51535, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_fe_best_model
# 104/104 [==============================] - 20s 190ms/step - loss: 0.6970 - accuracy: 0.5132 - val_loss: 0.6952 - val_accuracy: 0.5154
# Epoch 7/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.6949 - accuracy: 0.5169
# Epoch 7: val_accuracy improved from 0.51535 to 0.52536, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_fe_best_model
# 104/104 [==============================] - 23s 219ms/step - loss: 0.6948 - accuracy: 0.5174 - val_loss: 0.6926 - val_accuracy: 0.5254
# Epoch 8/20
# 104/104 [==============================] - ETA: 0s - loss: 0.6917 - accuracy: 0.5274
# Epoch 8: val_accuracy improved from 0.52536 to 0.52957, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_fe_best_model
# 104/104 [==============================] - 20s 197ms/step - loss: 0.6917 - accuracy: 0.5274 - val_loss: 0.6908 - val_accuracy: 0.5296
# Epoch 9/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.6907 - accuracy: 0.5333
# Epoch 9: val_accuracy improved from 0.52957 to 0.53974, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_fe_best_model
# 104/104 [==============================] - 19s 187ms/step - loss: 0.6907 - accuracy: 0.5331 - val_loss: 0.6888 - val_accuracy: 0.5397
# Epoch 10/20
# 104/104 [==============================] - ETA: 0s - loss: 0.6887 - accuracy: 0.5354
# Epoch 10: val_accuracy improved from 0.53974 to 0.54466, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_fe_best_model
# 104/104 [==============================] - 23s 226ms/step - loss: 0.6887 - accuracy: 0.5354 - val_loss: 0.6879 - val_accuracy: 0.5447
# Epoch 11/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.6875 - accuracy: 0.5438
# Epoch 11: val_accuracy improved from 0.54466 to 0.54834, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_fe_best_model
# 104/104 [==============================] - 20s 197ms/step - loss: 0.6874 - accuracy: 0.5439 - val_loss: 0.6867 - val_accuracy: 0.5483
# Epoch 12/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.6864 - accuracy: 0.5482
# Epoch 12: val_accuracy improved from 0.54834 to 0.55325, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_fe_best_model
# 104/104 [==============================] - 19s 187ms/step - loss: 0.6864 - accuracy: 0.5481 - val_loss: 0.6854 - val_accuracy: 0.5533
# Epoch 13/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.6854 - accuracy: 0.5541
# Epoch 13: val_accuracy improved from 0.55325 to 0.55554, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_fe_best_model
# 104/104 [==============================] - 20s 198ms/step - loss: 0.6854 - accuracy: 0.5541 - val_loss: 0.6842 - val_accuracy: 0.5555
# Epoch 14/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.6844 - accuracy: 0.5621
# Epoch 14: val_accuracy improved from 0.55554 to 0.56045, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_fe_best_model
# 104/104 [==============================] - 23s 224ms/step - loss: 0.6845 - accuracy: 0.5617 - val_loss: 0.6835 - val_accuracy: 0.5604
# Epoch 15/20
# 104/104 [==============================] - ETA: 0s - loss: 0.6835 - accuracy: 0.5606
# Epoch 15: val_accuracy improved from 0.56045 to 0.56168, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_fe_best_model
# 104/104 [==============================] - 20s 198ms/step - loss: 0.6835 - accuracy: 0.5606 - val_loss: 0.6825 - val_accuracy: 0.5617
# Epoch 16/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.6834 - accuracy: 0.5632
# Epoch 16: val_accuracy improved from 0.56168 to 0.56536, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_fe_best_model
# 104/104 [==============================] - 20s 192ms/step - loss: 0.6833 - accuracy: 0.5636 - val_loss: 0.6818 - val_accuracy: 0.5654
# Epoch 17/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.6817 - accuracy: 0.5703
# Epoch 17: val_accuracy did not improve from 0.56536
# 104/104 [==============================] - 4s 38ms/step - loss: 0.6817 - accuracy: 0.5704 - val_loss: 0.6819 - val_accuracy: 0.5624
# Epoch 18/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.6812 - accuracy: 0.5706
# Epoch 18: val_accuracy improved from 0.56536 to 0.56817, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_fe_best_model
# 104/104 [==============================] - 23s 225ms/step - loss: 0.6812 - accuracy: 0.5708 - val_loss: 0.6806 - val_accuracy: 0.5682
# Epoch 19/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.6820 - accuracy: 0.5661
# Epoch 19: val_accuracy improved from 0.56817 to 0.56940, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_gru_fe_best_model
# 104/104 [==============================] - 19s 189ms/step - loss: 0.6821 - accuracy: 0.5659 - val_loss: 0.6802 - val_accuracy: 0.5694
# Epoch 20/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.6811 - accuracy: 0.5694
# Epoch 20: val_accuracy did not improve from 0.56940
# 104/104 [==============================] - 4s 34ms/step - loss: 0.6811 - accuracy: 0.5691 - val_loss: 0.6803 - val_accuracy: 0.5659
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
best_model_fe = load_model(fe_checkpoint_path)
score_fe, acc_fe = best_model_fe.evaluate(X_test_y, y_test_y, verbose=0)
print(f'Test loss for feature extractor BiLSTM-GRU model on Yelp dataset: {score_fe:.3f}')
print(f'Test accuracy for feature extractor BiLSTM-GRU model on Yelp dataset: {acc_fe:.3f}')
# Out:
# Test loss for feature extractor BiLSTM-GRU model on Yelp dataset: 0.677
# Test accuracy for feature extractor BiLSTM-GRU model on Yelp dataset: 0.590
