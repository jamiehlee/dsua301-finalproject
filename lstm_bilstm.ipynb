# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
import itertools
from sklearn.model_selection import train_test_split
from spacy.tokenizer import Tokenizer
from spacy.lang.en import English
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import LSTM, Embedding
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Bidirectional
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
# read preprocessed data
train = pd.read_csv("./train_sampled_reviews.csv")
val = pd.read_csv("./val_sampled_reviews.csv")
test = pd.read_csv("./test_sampled_reviews.csv")

# %%
train_texts = train['Review'].to_numpy()
train_labels = train['Label'].to_numpy()
val_texts = val['Review'].to_numpy()
val_labels = val['Label'].to_numpy()
test_texts = test['Review'].to_numpy()
test_labels = test['Label'].to_numpy()

# %%
def process_tokens(text):
    """
    function to process tokens, replace any unwanted chars
    """
    preprocessed_text = text.lower().replace(",", "").replace(".", "").replace(":", "").replace(")", "").replace("-", "").replace("(", "")
    preprocessed_text = ''.join([i for i in preprocessed_text if not preprocessed_text.isdigit()])
    return preprocessed_text

'''def preprocessing(data, tokenizer):
    """
    preprocessing data to list of tokens
    """
    nlp = English()
    tokenizer = tokenizer(nlp.vocab)
    preprocessed_data = []
    for sentence in data:
        sentence = process_tokens(sentence)
        tokens = tokenizer(sentence)
        tlist = []
        for token in tokens:
            tlist.append(str(token))
        preprocessed_data.append(tlist)
    return preprocessed_data'''

def preprocessing(data, tokenizer):
    preprocessed_data = []
    for sentence in data:
        sentence = process_tokens(sentence)
        tokens = tokenizer(sentence)
        tlist = []
        for token in tokens:
            tlist.append(str(token))
        preprocessed_data.append(tlist)
    return preprocessed_data

nlp = English()
tokenizer = Tokenizer(nlp.vocab)
train_data = preprocessing(train_texts, tokenizer)
val_data = preprocessing(val_texts, tokenizer)
test_data = preprocessing(test_texts, tokenizer)

## Creating a vectorizer to vectorize text and create matrix of features
## Bag of words technique
class Vectorizer():
    def __init__(self, max_features):
        self.max_features = max_features
        self.vocab_list = None
        self.token_to_index = None

    def fit(self, dataset):
        word_dict = {}
        for sentence in dataset:
            for token in sentence:
                if token not in word_dict:
                    word_dict[token] = 1
                else:
                    word_dict[token] += 1
        word_dict = dict(sorted(word_dict.items(), key=lambda item: item[1], reverse=True))
        end_to_slice = min(len(word_dict), self.max_features)
        word_dict = dict(itertools.islice(word_dict.items(), end_to_slice))
        self.vocab_list = list(word_dict.keys())
        self.token_to_index = {}
        counter = 0
        for token in self.vocab_list:
            self.token_to_index[token] = counter
            counter += 1


    def transform(self, dataset):
        data_matrix = np.zeros((len(dataset), len(self.vocab_list)))
        for i, sentence in enumerate(dataset):
            for token in sentence:
                if token in self.token_to_index:
                    data_matrix[i, self.token_to_index[token]] += 1
        return data_matrix

## max features - top k words to consider only
max_features = 2000

vectorizer = Vectorizer(max_features=max_features)
vectorizer.fit(train_data)

## Checking if the len of vocab = k
X_train = vectorizer.transform(train_data)
X_val = vectorizer.transform(val_data)
X_test = vectorizer.transform(test_data)

y_train = np.array(train_labels)
y_val = np.array(val_labels)
y_test = np.array(test_labels)

vocab = vectorizer.vocab_list

# %%
X_train.shape
# Out:
# (24000, 2000)

# %%
y_train[:10]
# Out:
# array([0, 0, 1, 0, 0, 0, 0, 1, 0, 1])

# %%
y_train = y_train.astype('int')
y_val = y_val.astype('int')
y_test = y_test.astype('int')

y_train = to_categorical(y_train, 2)
y_val = to_categorical(y_val, 2)
y_test = to_categorical(y_test, 2)

X_train = X_train.reshape(-1, 1, X_train.shape[1])
X_val = X_val.reshape(-1, 1, X_val.shape[1])
X_test = X_test.reshape(-1, 1, X_test.shape[1])

y_train = y_train.reshape(-1, 2)
y_val = y_val.reshape(-1, 2)
y_test = y_test.reshape(-1, 2)

print(f'X_train.shape: {X_train.shape}, y_train.shape: {y_train.shape}')
# Out:
# X_train.shape: (24000, 1, 2000), y_train.shape: (24000, 2)

# %% [markdown]
# ## LSTM Model

# %%
X_train.dtype
# Out:
# dtype('float64')

# %%
model_lstm = None
model_lstm = Sequential()
model_lstm.add(LSTM(64, input_shape=(1, max_features), dropout=0.4))
model_lstm.add(Dense(2, activation='softmax'))

optimizer = Adam(learning_rate=0.01)
model_lstm.compile(loss='categorical_crossentropy', optimizer=optimizer,
              metrics=['accuracy'])

lstm_checkpoint_path = '/content/drive/MyDrive/advanced_project/models/lstm_best_model'
lstm_checkpoint = ModelCheckpoint(
    filepath=lstm_checkpoint_path,
    save_best_only=True,  # Only save the best model
    monitor='val_accuracy',  # Monitor validation accuracy
    mode='max',  # Save the model when validation accuracy improves
    verbose=1  # Print messages about the saving process
)

print(model_lstm.summary())
history_lstm = model_lstm.fit(X_train, y_train,
          batch_size=256,
          validation_data=(X_val, y_val),
          epochs=20,
          callbacks=[lstm_checkpoint])

print(history_lstm.history.keys())
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_12 (LSTM)              (None, 64)                528640
#
#  dense_11 (Dense)            (None, 2)                 130
#
# =================================================================
# Total params: 528770 (2.02 MB)
# Trainable params: 528770 (2.02 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/20
# 93/94 [============================>.] - ETA: 0s - loss: 0.4582 - accuracy: 0.7747
# Epoch 1: val_accuracy improved from -inf to 0.87472, saving model to /content/drive/MyDrive/advanced_project/models/lstm_best_model
# 94/94 [==============================] - 10s 86ms/step - loss: 0.4583 - accuracy: 0.7746 - val_loss: 0.3140 - val_accuracy: 0.8747
# Epoch 2/20
# 94/94 [==============================] - ETA: 0s - loss: 0.3784 - accuracy: 0.8283
# Epoch 2: val_accuracy improved from 0.87472 to 0.89444, saving model to /content/drive/MyDrive/advanced_project/models/lstm_best_model
# 94/94 [==============================] - 7s 80ms/step - loss: 0.3784 - accuracy: 0.8283 - val_loss: 0.2661 - val_accuracy: 0.8944
# Epoch 3/20
# 93/94 [============================>.] - ETA: 0s - loss: 0.3595 - accuracy: 0.8360
# Epoch 3: val_accuracy improved from 0.89444 to 0.90167, saving model to /content/drive/MyDrive/advanced_project/models/lstm_best_model
# 94/94 [==============================] - 11s 119ms/step - loss: 0.3598 - accuracy: 0.8359 - val_loss: 0.2436 - val_accuracy: 0.9017
# Epoch 4/20
# 93/94 [============================>.] - ETA: 0s - loss: 0.3373 - accuracy: 0.8488
# Epoch 4: val_accuracy improved from 0.90167 to 0.91944, saving model to /content/drive/MyDrive/advanced_project/models/lstm_best_model
# 94/94 [==============================] - 7s 71ms/step - loss: 0.3375 - accuracy: 0.8487 - val_loss: 0.2108 - val_accuracy: 0.9194
# Epoch 5/20
# 94/94 [==============================] - ETA: 0s - loss: 0.3152 - accuracy: 0.8605
# Epoch 5: val_accuracy improved from 0.91944 to 0.93778, saving model to /content/drive/MyDrive/advanced_project/models/lstm_best_model
# 94/94 [==============================] - 9s 98ms/step - loss: 0.3152 - accuracy: 0.8605 - val_loss: 0.1816 - val_accuracy: 0.9378
# Epoch 6/20
# 93/94 [============================>.] - ETA: 0s - loss: 0.3062 - accuracy: 0.8606
# Epoch 6: val_accuracy improved from 0.93778 to 0.95167, saving model to /content/drive/MyDrive/advanced_project/models/lstm_best_model
# 94/94 [==============================] - 7s 71ms/step - loss: 0.3064 - accuracy: 0.8607 - val_loss: 0.1518 - val_accuracy: 0.9517
# Epoch 7/20
# 94/94 [==============================] - ETA: 0s - loss: 0.2879 - accuracy: 0.8748
# Epoch 7: val_accuracy improved from 0.95167 to 0.96306, saving model to /content/drive/MyDrive/advanced_project/models/lstm_best_model
# 94/94 [==============================] - 8s 87ms/step - loss: 0.2879 - accuracy: 0.8748 - val_loss: 0.1292 - val_accuracy: 0.9631
# Epoch 8/20
# 93/94 [============================>.] - ETA: 0s - loss: 0.2722 - accuracy: 0.8821
# Epoch 8: val_accuracy improved from 0.96306 to 0.96833, saving model to /content/drive/MyDrive/advanced_project/models/lstm_best_model
# 94/94 [==============================] - 6s 69ms/step - loss: 0.2727 - accuracy: 0.8816 - val_loss: 0.1206 - val_accuracy: 0.9683
# Epoch 9/20
# 94/94 [==============================] - ETA: 0s - loss: 0.2643 - accuracy: 0.8852
# Epoch 9: val_accuracy improved from 0.96833 to 0.97694, saving model to /content/drive/MyDrive/advanced_project/models/lstm_best_model
# 94/94 [==============================] - 8s 86ms/step - loss: 0.2643 - accuracy: 0.8852 - val_loss: 0.1062 - val_accuracy: 0.9769
# Epoch 10/20
# 92/94 [============================>.] - ETA: 0s - loss: 0.2511 - accuracy: 0.8925
# Epoch 10: val_accuracy improved from 0.97694 to 0.97861, saving model to /content/drive/MyDrive/advanced_project/models/lstm_best_model
# 94/94 [==============================] - 6s 69ms/step - loss: 0.2513 - accuracy: 0.8925 - val_loss: 0.0883 - val_accuracy: 0.9786
# Epoch 11/20
# 93/94 [============================>.] - ETA: 0s - loss: 0.2458 - accuracy: 0.8952
# Epoch 11: val_accuracy improved from 0.97861 to 0.98528, saving model to /content/drive/MyDrive/advanced_project/models/lstm_best_model
# 94/94 [==============================] - 8s 83ms/step - loss: 0.2459 - accuracy: 0.8950 - val_loss: 0.0813 - val_accuracy: 0.9853
# Epoch 12/20
# 93/94 [============================>.] - ETA: 0s - loss: 0.2389 - accuracy: 0.8981
# Epoch 12: val_accuracy improved from 0.98528 to 0.98694, saving model to /content/drive/MyDrive/advanced_project/models/lstm_best_model
# 94/94 [==============================] - 7s 72ms/step - loss: 0.2395 - accuracy: 0.8980 - val_loss: 0.0710 - val_accuracy: 0.9869
# Epoch 13/20
# 92/94 [============================>.] - ETA: 0s - loss: 0.2360 - accuracy: 0.9001
# Epoch 13: val_accuracy improved from 0.98694 to 0.98972, saving model to /content/drive/MyDrive/advanced_project/models/lstm_best_model
# 94/94 [==============================] - 7s 80ms/step - loss: 0.2364 - accuracy: 0.8997 - val_loss: 0.0620 - val_accuracy: 0.9897
# Epoch 14/20
# 93/94 [============================>.] - ETA: 0s - loss: 0.2213 - accuracy: 0.9057
# Epoch 14: val_accuracy improved from 0.98972 to 0.99333, saving model to /content/drive/MyDrive/advanced_project/models/lstm_best_model
# 94/94 [==============================] - 7s 79ms/step - loss: 0.2218 - accuracy: 0.9057 - val_loss: 0.0541 - val_accuracy: 0.9933
# Epoch 15/20
# 92/94 [============================>.] - ETA: 0s - loss: 0.2135 - accuracy: 0.9099
# Epoch 15: val_accuracy did not improve from 0.99333
# 94/94 [==============================] - 3s 28ms/step - loss: 0.2141 - accuracy: 0.9096 - val_loss: 0.0564 - val_accuracy: 0.9889
# Epoch 16/20
# 92/94 [============================>.] - ETA: 0s - loss: 0.2147 - accuracy: 0.9110
# Epoch 16: val_accuracy improved from 0.99333 to 0.99472, saving model to /content/drive/MyDrive/advanced_project/models/lstm_best_model
# 94/94 [==============================] - 11s 119ms/step - loss: 0.2151 - accuracy: 0.9110 - val_loss: 0.0440 - val_accuracy: 0.9947
# Epoch 17/20
# 93/94 [============================>.] - ETA: 0s - loss: 0.2018 - accuracy: 0.9150
# Epoch 17: val_accuracy did not improve from 0.99472
# 94/94 [==============================] - 3s 27ms/step - loss: 0.2015 - accuracy: 0.9153 - val_loss: 0.0410 - val_accuracy: 0.9947
# Epoch 18/20
# 94/94 [==============================] - ETA: 0s - loss: 0.1992 - accuracy: 0.9143
# Epoch 18: val_accuracy improved from 0.99472 to 0.99667, saving model to /content/drive/MyDrive/advanced_project/models/lstm_best_model
# 94/94 [==============================] - 8s 86ms/step - loss: 0.1992 - accuracy: 0.9143 - val_loss: 0.0375 - val_accuracy: 0.9967
# Epoch 19/20
# 93/94 [============================>.] - ETA: 0s - loss: 0.2007 - accuracy: 0.9160
# Epoch 19: val_accuracy did not improve from 0.99667
# 94/94 [==============================] - 3s 32ms/step - loss: 0.2008 - accuracy: 0.9160 - val_loss: 0.0369 - val_accuracy: 0.9953
# Epoch 20/20
# 93/94 [============================>.] - ETA: 0s - loss: 0.1961 - accuracy: 0.9189
# Epoch 20: val_accuracy did not improve from 0.99667
# 94/94 [==============================] - 3s 28ms/step - loss: 0.1963 - accuracy: 0.9189 - val_loss: 0.0329 - val_accuracy: 0.9964
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# ## BiLSTM Model

# %%
model_bilstm = None
model_bilstm = Sequential()
model_bilstm.add(Bidirectional(LSTM(64, dropout=0.4), input_shape=(1, max_features)))
model_bilstm.add(Dense(2, activation='softmax'))

optimizer = Adam(learning_rate=0.01)
model_bilstm.compile(loss='categorical_crossentropy', optimizer=optimizer,
              metrics=['accuracy'])

bilstm_checkpoint_path = '/content/drive/MyDrive/advanced_project/models/bilstm_best_model'
bilstm_checkpoint = ModelCheckpoint(
    filepath=bilstm_checkpoint_path,
    save_best_only=True,  # Only save the best model
    monitor='val_accuracy',  # Monitor validation accuracy
    mode='max',  # Save the model when validation accuracy improves
    verbose=1  # Print messages about the saving process
)

print(model_bilstm.summary())
history_bilstm = model_bilstm.fit(X_train, y_train,
          batch_size=256,
          validation_data=(X_val, y_val),
          epochs=20,
          callbacks=[bilstm_checkpoint])
print(history_bilstm.history.keys())
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirecti  (None, 128)               1057280
#  onal)
#
#  dense_12 (Dense)            (None, 2)                 258
#
# =================================================================
# Total params: 1057538 (4.03 MB)
# Trainable params: 1057538 (4.03 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/20
# 94/94 [==============================] - ETA: 0s - loss: 0.4216 - accuracy: 0.8003
# Epoch 1: val_accuracy improved from -inf to 0.88694, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_best_model
# 94/94 [==============================] - 25s 224ms/step - loss: 0.4216 - accuracy: 0.8003 - val_loss: 0.2751 - val_accuracy: 0.8869
# Epoch 2/20
# 93/94 [============================>.] - ETA: 0s - loss: 0.3285 - accuracy: 0.8543
# Epoch 2: val_accuracy improved from 0.88694 to 0.91139, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_best_model
# 94/94 [==============================] - 18s 191ms/step - loss: 0.3286 - accuracy: 0.8543 - val_loss: 0.2275 - val_accuracy: 0.9114
# Epoch 3/20
# 94/94 [==============================] - ETA: 0s - loss: 0.3041 - accuracy: 0.8657
# Epoch 3: val_accuracy improved from 0.91139 to 0.92389, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_best_model
# 94/94 [==============================] - 21s 224ms/step - loss: 0.3041 - accuracy: 0.8657 - val_loss: 0.1950 - val_accuracy: 0.9239
# Epoch 4/20
# 94/94 [==============================] - ETA: 0s - loss: 0.2835 - accuracy: 0.8761
# Epoch 4: val_accuracy improved from 0.92389 to 0.94222, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_best_model
# 94/94 [==============================] - 22s 232ms/step - loss: 0.2835 - accuracy: 0.8761 - val_loss: 0.1694 - val_accuracy: 0.9422
# Epoch 5/20
# 93/94 [============================>.] - ETA: 0s - loss: 0.2519 - accuracy: 0.8932
# Epoch 5: val_accuracy improved from 0.94222 to 0.96167, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_best_model
# 94/94 [==============================] - 20s 210ms/step - loss: 0.2533 - accuracy: 0.8928 - val_loss: 0.1280 - val_accuracy: 0.9617
# Epoch 6/20
# 94/94 [==============================] - ETA: 0s - loss: 0.2350 - accuracy: 0.9024
# Epoch 6: val_accuracy improved from 0.96167 to 0.97083, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_best_model
# 94/94 [==============================] - 18s 196ms/step - loss: 0.2350 - accuracy: 0.9024 - val_loss: 0.1047 - val_accuracy: 0.9708
# Epoch 7/20
# 93/94 [============================>.] - ETA: 0s - loss: 0.2158 - accuracy: 0.9074
# Epoch 7: val_accuracy improved from 0.97083 to 0.98139, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_best_model
# 94/94 [==============================] - 21s 224ms/step - loss: 0.2160 - accuracy: 0.9074 - val_loss: 0.0860 - val_accuracy: 0.9814
# Epoch 8/20
# 94/94 [==============================] - ETA: 0s - loss: 0.1988 - accuracy: 0.9176
# Epoch 8: val_accuracy improved from 0.98139 to 0.98556, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_best_model
# 94/94 [==============================] - 18s 193ms/step - loss: 0.1988 - accuracy: 0.9176 - val_loss: 0.0675 - val_accuracy: 0.9856
# Epoch 9/20
# 94/94 [==============================] - ETA: 0s - loss: 0.1886 - accuracy: 0.9220
# Epoch 9: val_accuracy improved from 0.98556 to 0.98833, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_best_model
# 94/94 [==============================] - 19s 207ms/step - loss: 0.1886 - accuracy: 0.9220 - val_loss: 0.0568 - val_accuracy: 0.9883
# Epoch 10/20
# 94/94 [==============================] - ETA: 0s - loss: 0.1777 - accuracy: 0.9273
# Epoch 10: val_accuracy improved from 0.98833 to 0.99444, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_best_model
# 94/94 [==============================] - 19s 203ms/step - loss: 0.1777 - accuracy: 0.9273 - val_loss: 0.0437 - val_accuracy: 0.9944
# Epoch 11/20
# 94/94 [==============================] - ETA: 0s - loss: 0.1694 - accuracy: 0.9315
# Epoch 11: val_accuracy did not improve from 0.99444
# 94/94 [==============================] - 4s 46ms/step - loss: 0.1694 - accuracy: 0.9315 - val_loss: 0.0401 - val_accuracy: 0.9942
# Epoch 12/20
# 93/94 [============================>.] - ETA: 0s - loss: 0.1628 - accuracy: 0.9342
# Epoch 12: val_accuracy improved from 0.99444 to 0.99500, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_best_model
# 94/94 [==============================] - 21s 225ms/step - loss: 0.1630 - accuracy: 0.9340 - val_loss: 0.0313 - val_accuracy: 0.9950
# Epoch 13/20
# 94/94 [==============================] - ETA: 0s - loss: 0.1536 - accuracy: 0.9374
# Epoch 13: val_accuracy improved from 0.99500 to 0.99667, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_best_model
# 94/94 [==============================] - 19s 209ms/step - loss: 0.1536 - accuracy: 0.9374 - val_loss: 0.0272 - val_accuracy: 0.9967
# Epoch 14/20
# 93/94 [============================>.] - ETA: 0s - loss: 0.1414 - accuracy: 0.9430
# Epoch 14: val_accuracy did not improve from 0.99667
# 94/94 [==============================] - 5s 56ms/step - loss: 0.1414 - accuracy: 0.9429 - val_loss: 0.0234 - val_accuracy: 0.9967
# Epoch 15/20
# 93/94 [============================>.] - ETA: 0s - loss: 0.1446 - accuracy: 0.9394
# Epoch 15: val_accuracy improved from 0.99667 to 0.99778, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_best_model
# 94/94 [==============================] - 17s 186ms/step - loss: 0.1444 - accuracy: 0.9395 - val_loss: 0.0226 - val_accuracy: 0.9978
# Epoch 16/20
# 93/94 [============================>.] - ETA: 0s - loss: 0.1354 - accuracy: 0.9448
# Epoch 16: val_accuracy did not improve from 0.99778
# 94/94 [==============================] - 4s 47ms/step - loss: 0.1352 - accuracy: 0.9450 - val_loss: 0.0200 - val_accuracy: 0.9975
# Epoch 17/20
# 93/94 [============================>.] - ETA: 0s - loss: 0.1365 - accuracy: 0.9467
# Epoch 17: val_accuracy improved from 0.99778 to 0.99861, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_best_model
# 94/94 [==============================] - 19s 207ms/step - loss: 0.1364 - accuracy: 0.9466 - val_loss: 0.0158 - val_accuracy: 0.9986
# Epoch 18/20
# 93/94 [============================>.] - ETA: 0s - loss: 0.1243 - accuracy: 0.9498
# Epoch 18: val_accuracy improved from 0.99861 to 0.99889, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_best_model
# 94/94 [==============================] - 23s 242ms/step - loss: 0.1245 - accuracy: 0.9497 - val_loss: 0.0152 - val_accuracy: 0.9989
# Epoch 19/20
# 94/94 [==============================] - ETA: 0s - loss: 0.1255 - accuracy: 0.9511
# Epoch 19: val_accuracy improved from 0.99889 to 0.99917, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_best_model
# 94/94 [==============================] - 18s 189ms/step - loss: 0.1255 - accuracy: 0.9511 - val_loss: 0.0144 - val_accuracy: 0.9992
# Epoch 20/20
# 93/94 [============================>.] - ETA: 0s - loss: 0.1196 - accuracy: 0.9535
# Epoch 20: val_accuracy did not improve from 0.99917
# 94/94 [==============================] - 5s 49ms/step - loss: 0.1199 - accuracy: 0.9534 - val_loss: 0.0130 - val_accuracy: 0.9978
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# ##Eval on Test Set

# %%
# test best models on test set
best_lstm = load_model(lstm_checkpoint_path)
score_lstm, acc_lstm = best_lstm.evaluate(X_test, y_test, verbose=0)
print(f'Test loss for LSTM model: {score_lstm:.3f}')
print(f'Test accuracy for LSTM model: {acc_lstm:.3f}')
print()

best_bilstm = load_model(bilstm_checkpoint_path)
score_bilstm, acc_bilstm = best_bilstm.evaluate(X_test, y_test, verbose=0)
print(f'Test loss for BiLSTM model: {score_bilstm:.3f}')
print(f'Test accuracy for BiLSTM model: {acc_bilstm:.3f}')
# Out:
# Test loss for LSTM model: 0.372
# Test accuracy for LSTM model: 0.858
#
# Test loss for BiLSTM model: 0.430
# Test accuracy for BiLSTM model: 0.857

# %% [markdown]
# ##Test on Yelp Review Dataset

# %%
yelp_train = pd.read_csv('yelp_train.csv')
yelp_val = pd.read_csv('yelp_val.csv')
yelp_test = pd.read_csv('yelp_test.csv')

yelp_train.head()
# Out:
#    Unnamed: 0  Label                                             Review
# 0        5724      1  i was a feeling a little abandoned in creepy t...
# 1       22162      1  The food & atmosphere at Sushi Rock is awesome...
# 2       18039      0  2.5  stars. Did I come on the wrong day? We ca...
# 3        1987      1  Food here is great, had the chicken schwarma w...
# 4       11590      1  I was really craving some Asian noodles, so af...

# %%
yelp_train = yelp_train.drop(['Unnamed: 0'], axis=1)
yelp_val = yelp_val.drop(['Unnamed: 0'], axis=1)
yelp_test = yelp_test.drop(['Unnamed: 0'], axis=1)

yelp_train.head()
# Out:
#    Label                                             Review
# 0      1  i was a feeling a little abandoned in creepy t...
# 1      1  The food & atmosphere at Sushi Rock is awesome...
# 2      0  2.5  stars. Did I come on the wrong day? We ca...
# 3      1  Food here is great, had the chicken schwarma w...
# 4      1  I was really craving some Asian noodles, so af...

# %%
train_labels_y, train_texts_y = yelp_train.values[:,0], yelp_train.values[:,1]
val_labels_y, val_texts_y = yelp_val.values[:,0], yelp_val.values[:,1]
test_labels_y, test_texts_y = yelp_test.values[:,0], yelp_test.values[:,1]

# %%
nlp = English()
tokenizer = Tokenizer(nlp.vocab)

train_data_y = preprocessing(train_texts_y, tokenizer)
val_data_y = preprocessing(val_texts_y, tokenizer)
test_data_y = preprocessing(test_texts_y, tokenizer)

# %%
## max features - top k words to consider only
max_features = 2000

vectorizer_y = Vectorizer(max_features=max_features)
vectorizer_y.fit(train_data_y)

## Checking if the len of vocab = k
X_train_y = vectorizer_y.transform(train_data_y)
X_val_y = vectorizer_y.transform(val_data_y)
X_test_y = vectorizer_y.transform(test_data_y)

y_train_y = np.array(train_labels_y)
y_val_y = np.array(val_labels_y)
y_test_y = np.array(test_labels_y)

vocab_y = vectorizer_y.vocab_list

# %%
y_train_y = y_train_y.astype('int')
y_val_y = y_val_y.astype('int')
y_test_y = y_test_y.astype('int')

y_train_y = to_categorical(y_train_y, 2)
y_val_y = to_categorical(y_val_y, 2)
y_test_y = to_categorical(y_test_y, 2)

X_train_y = X_train_y.reshape(-1, 1, X_train_y.shape[1])
X_val_y = X_val_y.reshape(-1, 1, X_val_y.shape[1])
X_test_y = X_test_y.reshape(-1, 1, X_test_y.shape[1])

y_train_y = y_train_y.reshape(-1, 2)
y_val_y = y_val_y.reshape(-1, 2)
y_test_y = y_test_y.reshape(-1, 2)

print(f'X_train_y.shape: {X_train_y.shape}, y_train_y.shape: {y_train_y.shape}')
# Out:
# X_train_y.shape: (26600, 1, 2000), y_train_y.shape: (26600, 2)

# %%
best_lstm = load_model(lstm_checkpoint_path)

score_lstm_y, acc_lstm_y = best_lstm.evaluate(X_test_y, y_test_y, verbose=0)
print(f'Test loss for LSTM model: {score_lstm_y:.3f}')
print(f'Test accuracy for LSTM model: {acc_lstm_y:.3f}')
print()
# Out:
# Test loss for LSTM model: 1.396
# Test accuracy for LSTM model: 0.525

# %%
best_bilstm = load_model(bilstm_checkpoint_path)

score_bilstm_y, acc_bilstm_y = best_bilstm.evaluate(X_test_y, y_test_y, verbose=0)
print(f'Test loss for BiLSTM model: {score_bilstm_y:.3f}')
print(f'Test accuracy for BiLSTM model: {acc_bilstm_y:.3f}')
print()
# Out:
# Test loss for BiLSTM model: 1.746
# Test accuracy for BiLSTM model: 0.546

# %%
# finetuning LSTM
model_lstm_finetuned = load_model(lstm_checkpoint_path)

optimizer = Adam(learning_rate=0.001)

model_lstm_finetuned.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

lstm_ft_checkpoint_path = '/content/drive/MyDrive/advanced_project/models/lstm_finetuned_best_model'
lstm_ft_checkpoint = ModelCheckpoint(
    filepath=lstm_ft_checkpoint_path,
    save_best_only=True,
    monitor='val_accuracy',
    mode='max',
    verbose=1
)

history_lstm_ft = model_lstm_finetuned.fit(
    X_train_y, y_train_y,
    batch_size=256,
    validation_data=(X_val_y, y_val_y),
    epochs=20,
    callbacks=[lstm_ft_checkpoint]
)

# Print history keys
print(history_lstm_ft.history.keys())
# Out:
# Epoch 1/20
# 104/104 [==============================] - ETA: 0s - loss: 1.1323 - accuracy: 0.5476
# Epoch 1: val_accuracy improved from -inf to 0.57607, saving model to /content/drive/MyDrive/advanced_project/models/lstm_finetuned_best_model
# 104/104 [==============================] - 12s 90ms/step - loss: 1.1323 - accuracy: 0.5476 - val_loss: 0.7945 - val_accuracy: 0.5761
# Epoch 2/20
# 102/104 [============================>.] - ETA: 0s - loss: 0.8023 - accuracy: 0.5929
# Epoch 2: val_accuracy improved from 0.57607 to 0.63344, saving model to /content/drive/MyDrive/advanced_project/models/lstm_finetuned_best_model
# 104/104 [==============================] - 7s 63ms/step - loss: 0.8014 - accuracy: 0.5930 - val_loss: 0.6660 - val_accuracy: 0.6334
# Epoch 3/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.6924 - accuracy: 0.6327
# Epoch 3: val_accuracy improved from 0.63344 to 0.68152, saving model to /content/drive/MyDrive/advanced_project/models/lstm_finetuned_best_model
# 104/104 [==============================] - 9s 85ms/step - loss: 0.6922 - accuracy: 0.6330 - val_loss: 0.6100 - val_accuracy: 0.6815
# Epoch 4/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.6321 - accuracy: 0.6678
# Epoch 4: val_accuracy improved from 0.68152 to 0.72644, saving model to /content/drive/MyDrive/advanced_project/models/lstm_finetuned_best_model
# 104/104 [==============================] - 7s 64ms/step - loss: 0.6318 - accuracy: 0.6682 - val_loss: 0.5566 - val_accuracy: 0.7264
# Epoch 5/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.5806 - accuracy: 0.7100
# Epoch 5: val_accuracy improved from 0.72644 to 0.77364, saving model to /content/drive/MyDrive/advanced_project/models/lstm_finetuned_best_model
# 104/104 [==============================] - 8s 82ms/step - loss: 0.5805 - accuracy: 0.7101 - val_loss: 0.4959 - val_accuracy: 0.7736
# Epoch 6/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.5249 - accuracy: 0.7444
# Epoch 6: val_accuracy improved from 0.77364 to 0.80277, saving model to /content/drive/MyDrive/advanced_project/models/lstm_finetuned_best_model
# 104/104 [==============================] - 7s 64ms/step - loss: 0.5241 - accuracy: 0.7451 - val_loss: 0.4386 - val_accuracy: 0.8028
# Epoch 7/20
# 104/104 [==============================] - ETA: 0s - loss: 0.4811 - accuracy: 0.7704
# Epoch 7: val_accuracy improved from 0.80277 to 0.82014, saving model to /content/drive/MyDrive/advanced_project/models/lstm_finetuned_best_model
# 104/104 [==============================] - 9s 83ms/step - loss: 0.4811 - accuracy: 0.7704 - val_loss: 0.3952 - val_accuracy: 0.8201
# Epoch 8/20
# 102/104 [============================>.] - ETA: 0s - loss: 0.4492 - accuracy: 0.7907
# Epoch 8: val_accuracy improved from 0.82014 to 0.83857, saving model to /content/drive/MyDrive/advanced_project/models/lstm_finetuned_best_model
# 104/104 [==============================] - 7s 64ms/step - loss: 0.4492 - accuracy: 0.7908 - val_loss: 0.3653 - val_accuracy: 0.8386
# Epoch 9/20
# 104/104 [==============================] - ETA: 0s - loss: 0.4191 - accuracy: 0.8083
# Epoch 9: val_accuracy improved from 0.83857 to 0.84945, saving model to /content/drive/MyDrive/advanced_project/models/lstm_finetuned_best_model
# 104/104 [==============================] - 8s 82ms/step - loss: 0.4191 - accuracy: 0.8083 - val_loss: 0.3445 - val_accuracy: 0.8494
# Epoch 10/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.4029 - accuracy: 0.8163
# Epoch 10: val_accuracy improved from 0.84945 to 0.85489, saving model to /content/drive/MyDrive/advanced_project/models/lstm_finetuned_best_model
# 104/104 [==============================] - 11s 106ms/step - loss: 0.4025 - accuracy: 0.8163 - val_loss: 0.3288 - val_accuracy: 0.8549
# Epoch 11/20
# 104/104 [==============================] - ETA: 0s - loss: 0.3807 - accuracy: 0.8297
# Epoch 11: val_accuracy improved from 0.85489 to 0.86173, saving model to /content/drive/MyDrive/advanced_project/models/lstm_finetuned_best_model
# 104/104 [==============================] - 8s 74ms/step - loss: 0.3807 - accuracy: 0.8297 - val_loss: 0.3185 - val_accuracy: 0.8617
# Epoch 12/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.3762 - accuracy: 0.8339
# Epoch 12: val_accuracy improved from 0.86173 to 0.86928, saving model to /content/drive/MyDrive/advanced_project/models/lstm_finetuned_best_model
# 104/104 [==============================] - 7s 70ms/step - loss: 0.3762 - accuracy: 0.8337 - val_loss: 0.3077 - val_accuracy: 0.8693
# Epoch 13/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.3624 - accuracy: 0.8411
# Epoch 13: val_accuracy improved from 0.86928 to 0.87156, saving model to /content/drive/MyDrive/advanced_project/models/lstm_finetuned_best_model
# 104/104 [==============================] - 8s 78ms/step - loss: 0.3627 - accuracy: 0.8411 - val_loss: 0.3014 - val_accuracy: 0.8716
# Epoch 14/20
# 102/104 [============================>.] - ETA: 0s - loss: 0.3541 - accuracy: 0.8439
# Epoch 14: val_accuracy improved from 0.87156 to 0.87700, saving model to /content/drive/MyDrive/advanced_project/models/lstm_finetuned_best_model
# 104/104 [==============================] - 7s 68ms/step - loss: 0.3547 - accuracy: 0.8435 - val_loss: 0.2920 - val_accuracy: 0.8770
# Epoch 15/20
# 104/104 [==============================] - ETA: 0s - loss: 0.3450 - accuracy: 0.8503
# Epoch 15: val_accuracy improved from 0.87700 to 0.87893, saving model to /content/drive/MyDrive/advanced_project/models/lstm_finetuned_best_model
# 104/104 [==============================] - 8s 79ms/step - loss: 0.3450 - accuracy: 0.8503 - val_loss: 0.2837 - val_accuracy: 0.8789
# Epoch 16/20
# 104/104 [==============================] - ETA: 0s - loss: 0.3375 - accuracy: 0.8543
# Epoch 16: val_accuracy improved from 0.87893 to 0.88349, saving model to /content/drive/MyDrive/advanced_project/models/lstm_finetuned_best_model
# 104/104 [==============================] - 7s 63ms/step - loss: 0.3375 - accuracy: 0.8543 - val_loss: 0.2788 - val_accuracy: 0.8835
# Epoch 17/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.3340 - accuracy: 0.8540
# Epoch 17: val_accuracy improved from 0.88349 to 0.88823, saving model to /content/drive/MyDrive/advanced_project/models/lstm_finetuned_best_model
# 104/104 [==============================] - 9s 83ms/step - loss: 0.3342 - accuracy: 0.8539 - val_loss: 0.2733 - val_accuracy: 0.8882
# Epoch 18/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.3285 - accuracy: 0.8583
# Epoch 18: val_accuracy did not improve from 0.88823
# 104/104 [==============================] - 3s 29ms/step - loss: 0.3286 - accuracy: 0.8583 - val_loss: 0.2724 - val_accuracy: 0.8875
# Epoch 19/20
# 102/104 [============================>.] - ETA: 0s - loss: 0.3243 - accuracy: 0.8605
# Epoch 19: val_accuracy improved from 0.88823 to 0.88858, saving model to /content/drive/MyDrive/advanced_project/models/lstm_finetuned_best_model
# 104/104 [==============================] - 8s 74ms/step - loss: 0.3235 - accuracy: 0.8608 - val_loss: 0.2684 - val_accuracy: 0.8886
# Epoch 20/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.3178 - accuracy: 0.8634
# Epoch 20: val_accuracy did not improve from 0.88858
# 104/104 [==============================] - 4s 36ms/step - loss: 0.3185 - accuracy: 0.8634 - val_loss: 0.2651 - val_accuracy: 0.8886
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
best_lstm_ft = load_model(lstm_ft_checkpoint_path)

score_lstm_ft, acc_lstm_ft = best_lstm_ft.evaluate(X_test_y, y_test_y, verbose=0)
print(f'Test loss for finetuned LSTM model: {score_lstm_ft:.3f}')
print(f'Test accuracy for finetuned LSTM model: {acc_lstm_ft:.3f}')
print()
# Out:
# Test loss for finetuned LSTM model: 0.265
# Test accuracy for finetuned LSTM model: 0.891

# %%
# finetuning BiLSTM
model_bilstm_finetuned = load_model(bilstm_checkpoint_path)

optimizer = Adam(learning_rate=0.001)

model_bilstm_finetuned.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

bilstm_ft_checkpoint_path = '/content/drive/MyDrive/advanced_project/models/bilstm_finetuned_best_model'
bilstm_ft_checkpoint = ModelCheckpoint(
    filepath=bilstm_ft_checkpoint_path,
    save_best_only=True,
    monitor='val_accuracy',
    mode='max',
    verbose=1
)

history_bilstm_ft = model_bilstm_finetuned.fit(
    X_train_y, y_train_y,
    batch_size=256,
    validation_data=(X_val_y, y_val_y),
    epochs=20,
    callbacks=[bilstm_ft_checkpoint]
)
# Out:
# Epoch 1/20
# 103/104 [============================>.] - ETA: 0s - loss: 1.3505 - accuracy: 0.5607
# Epoch 1: val_accuracy improved from -inf to 0.61572, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_finetuned_best_model
# 104/104 [==============================] - 24s 184ms/step - loss: 1.3485 - accuracy: 0.5608 - val_loss: 0.8857 - val_accuracy: 0.6157
# Epoch 2/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.8867 - accuracy: 0.6204
# Epoch 2: val_accuracy improved from 0.61572 to 0.66766, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_finetuned_best_model
# 104/104 [==============================] - 18s 173ms/step - loss: 0.8867 - accuracy: 0.6203 - val_loss: 0.6770 - val_accuracy: 0.6677
# Epoch 3/20
# 104/104 [==============================] - ETA: 0s - loss: 0.7249 - accuracy: 0.6584
# Epoch 3: val_accuracy improved from 0.66766 to 0.70416, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_finetuned_best_model
# 104/104 [==============================] - 19s 182ms/step - loss: 0.7249 - accuracy: 0.6584 - val_loss: 0.5949 - val_accuracy: 0.7042
# Epoch 4/20
# 104/104 [==============================] - ETA: 0s - loss: 0.6291 - accuracy: 0.6956
# Epoch 4: val_accuracy improved from 0.70416 to 0.75311, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_finetuned_best_model
# 104/104 [==============================] - 23s 223ms/step - loss: 0.6291 - accuracy: 0.6956 - val_loss: 0.5234 - val_accuracy: 0.7531
# Epoch 5/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.5440 - accuracy: 0.7411
# Epoch 5: val_accuracy improved from 0.75311 to 0.80681, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_finetuned_best_model
# 104/104 [==============================] - 18s 174ms/step - loss: 0.5440 - accuracy: 0.7411 - val_loss: 0.4397 - val_accuracy: 0.8068
# Epoch 6/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.4730 - accuracy: 0.7809
# Epoch 6: val_accuracy improved from 0.80681 to 0.83050, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_finetuned_best_model
# 104/104 [==============================] - 18s 172ms/step - loss: 0.4731 - accuracy: 0.7809 - val_loss: 0.3865 - val_accuracy: 0.8305
# Epoch 7/20
# 104/104 [==============================] - ETA: 0s - loss: 0.4261 - accuracy: 0.8109
# Epoch 7: val_accuracy improved from 0.83050 to 0.84629, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_finetuned_best_model
# 104/104 [==============================] - 18s 176ms/step - loss: 0.4261 - accuracy: 0.8109 - val_loss: 0.3511 - val_accuracy: 0.8463
# Epoch 8/20
# 104/104 [==============================] - ETA: 0s - loss: 0.3878 - accuracy: 0.8279
# Epoch 8: val_accuracy improved from 0.84629 to 0.86085, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_finetuned_best_model
# 104/104 [==============================] - 24s 231ms/step - loss: 0.3878 - accuracy: 0.8279 - val_loss: 0.3291 - val_accuracy: 0.8609
# Epoch 9/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.3647 - accuracy: 0.8425
# Epoch 9: val_accuracy improved from 0.86085 to 0.86735, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_finetuned_best_model
# 104/104 [==============================] - 18s 173ms/step - loss: 0.3644 - accuracy: 0.8427 - val_loss: 0.3115 - val_accuracy: 0.8673
# Epoch 10/20
# 104/104 [==============================] - ETA: 0s - loss: 0.3437 - accuracy: 0.8515
# Epoch 10: val_accuracy improved from 0.86735 to 0.87349, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_finetuned_best_model
# 104/104 [==============================] - 18s 171ms/step - loss: 0.3437 - accuracy: 0.8515 - val_loss: 0.2989 - val_accuracy: 0.8735
# Epoch 11/20
# 104/104 [==============================] - ETA: 0s - loss: 0.3312 - accuracy: 0.8589
# Epoch 11: val_accuracy improved from 0.87349 to 0.87910, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_finetuned_best_model
# 104/104 [==============================] - 18s 178ms/step - loss: 0.3312 - accuracy: 0.8589 - val_loss: 0.2880 - val_accuracy: 0.8791
# Epoch 12/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.3204 - accuracy: 0.8642
# Epoch 12: val_accuracy improved from 0.87910 to 0.88226, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_finetuned_best_model
# 104/104 [==============================] - 24s 233ms/step - loss: 0.3204 - accuracy: 0.8642 - val_loss: 0.2815 - val_accuracy: 0.8823
# Epoch 13/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.2988 - accuracy: 0.8746
# Epoch 13: val_accuracy improved from 0.88226 to 0.88542, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_finetuned_best_model
# 104/104 [==============================] - 18s 176ms/step - loss: 0.2982 - accuracy: 0.8748 - val_loss: 0.2749 - val_accuracy: 0.8854
# Epoch 14/20
# 104/104 [==============================] - ETA: 0s - loss: 0.2955 - accuracy: 0.8753
# Epoch 14: val_accuracy improved from 0.88542 to 0.88858, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_finetuned_best_model
# 104/104 [==============================] - 18s 173ms/step - loss: 0.2955 - accuracy: 0.8753 - val_loss: 0.2700 - val_accuracy: 0.8886
# Epoch 15/20
# 104/104 [==============================] - ETA: 0s - loss: 0.2897 - accuracy: 0.8779
# Epoch 15: val_accuracy improved from 0.88858 to 0.89016, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_finetuned_best_model
# 104/104 [==============================] - 23s 220ms/step - loss: 0.2897 - accuracy: 0.8779 - val_loss: 0.2637 - val_accuracy: 0.8902
# Epoch 16/20
# 104/104 [==============================] - ETA: 0s - loss: 0.2799 - accuracy: 0.8838
# Epoch 16: val_accuracy improved from 0.89016 to 0.89174, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_finetuned_best_model
# 104/104 [==============================] - 18s 178ms/step - loss: 0.2799 - accuracy: 0.8838 - val_loss: 0.2602 - val_accuracy: 0.8917
# Epoch 17/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.2766 - accuracy: 0.8857
# Epoch 17: val_accuracy improved from 0.89174 to 0.89454, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_finetuned_best_model
# 104/104 [==============================] - 21s 207ms/step - loss: 0.2764 - accuracy: 0.8858 - val_loss: 0.2562 - val_accuracy: 0.8945
# Epoch 18/20
# 104/104 [==============================] - ETA: 0s - loss: 0.2711 - accuracy: 0.8873
# Epoch 18: val_accuracy improved from 0.89454 to 0.89665, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_finetuned_best_model
# 104/104 [==============================] - 19s 183ms/step - loss: 0.2711 - accuracy: 0.8873 - val_loss: 0.2542 - val_accuracy: 0.8966
# Epoch 19/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.2665 - accuracy: 0.8898
# Epoch 19: val_accuracy did not improve from 0.89665
# 104/104 [==============================] - 7s 70ms/step - loss: 0.2663 - accuracy: 0.8900 - val_loss: 0.2508 - val_accuracy: 0.8952
# Epoch 20/20
# 104/104 [==============================] - ETA: 0s - loss: 0.2562 - accuracy: 0.8945
# Epoch 20: val_accuracy improved from 0.89665 to 0.89717, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_finetuned_best_model
# 104/104 [==============================] - 18s 173ms/step - loss: 0.2562 - accuracy: 0.8945 - val_loss: 0.2489 - val_accuracy: 0.8972

# %%
best_bilstm_ft = load_model(bilstm_ft_checkpoint_path)

score_bilstm_ft, acc_bilstm_ft = best_bilstm_ft.evaluate(X_test_y, y_test_y, verbose=0)
print(f'Test loss for finetuned BiLSTM model: {score_bilstm_ft:.3f}')
print(f'Test accuracy for finetuned BiLSTM model: {acc_bilstm_ft:.3f}')
print()
# Out:
# Test loss for finetuned BiLSTM model: 0.251
# Test accuracy for finetuned BiLSTM model: 0.898

# %%
# Feature extractor approach
model_lstm_fe = load_model(lstm_checkpoint_path)

model_lstm_fe.layers[-1].trainable = False
initial_layer1_weights_values = model_lstm_fe.layers[-1].get_weights()

optimizer = Adam(learning_rate=0.001)

model_lstm_fe.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

lstm_fe_checkpoint_path = '/content/drive/MyDrive/advanced_project/models/lstm_fe_best_model'
lstm_fe_checkpoint = ModelCheckpoint(
    filepath=lstm_fe_checkpoint_path,
    save_best_only=True,
    monitor='val_accuracy',
    mode='max',
    verbose=1
)

history_lstm_fe = model_lstm_fe.fit(
    X_train_y, y_train_y,
    batch_size=256,
    validation_data=(X_val_y, y_val_y),
    epochs=20,
    callbacks=[lstm_fe_checkpoint]
)

# Print history keys
print(history_lstm_fe.history.keys())
# Out:
# Epoch 1/20
# 102/104 [============================>.] - ETA: 0s - loss: 1.2008 - accuracy: 0.5482
# Epoch 1: val_accuracy improved from -inf to 0.57747, saving model to /content/drive/MyDrive/advanced_project/models/lstm_fe_best_model
# 104/104 [==============================] - 10s 76ms/step - loss: 1.1959 - accuracy: 0.5487 - val_loss: 0.8302 - val_accuracy: 0.5775
# Epoch 2/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.8523 - accuracy: 0.5987
# Epoch 2: val_accuracy improved from 0.57747 to 0.63871, saving model to /content/drive/MyDrive/advanced_project/models/lstm_fe_best_model
# 104/104 [==============================] - 12s 117ms/step - loss: 0.8520 - accuracy: 0.5988 - val_loss: 0.6836 - val_accuracy: 0.6387
# Epoch 3/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.7302 - accuracy: 0.6339
# Epoch 3: val_accuracy improved from 0.63871 to 0.67994, saving model to /content/drive/MyDrive/advanced_project/models/lstm_fe_best_model
# 104/104 [==============================] - 9s 83ms/step - loss: 0.7298 - accuracy: 0.6341 - val_loss: 0.6219 - val_accuracy: 0.6799
# Epoch 4/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.6601 - accuracy: 0.6660
# Epoch 4: val_accuracy improved from 0.67994 to 0.72521, saving model to /content/drive/MyDrive/advanced_project/models/lstm_fe_best_model
# 104/104 [==============================] - 7s 67ms/step - loss: 0.6595 - accuracy: 0.6665 - val_loss: 0.5706 - val_accuracy: 0.7252
# Epoch 5/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.6074 - accuracy: 0.7024
# Epoch 5: val_accuracy improved from 0.72521 to 0.76382, saving model to /content/drive/MyDrive/advanced_project/models/lstm_fe_best_model
# 104/104 [==============================] - 9s 84ms/step - loss: 0.6076 - accuracy: 0.7024 - val_loss: 0.5183 - val_accuracy: 0.7638
# Epoch 6/20
# 104/104 [==============================] - ETA: 0s - loss: 0.5528 - accuracy: 0.7344
# Epoch 6: val_accuracy improved from 0.76382 to 0.79786, saving model to /content/drive/MyDrive/advanced_project/models/lstm_fe_best_model
# 104/104 [==============================] - 7s 68ms/step - loss: 0.5528 - accuracy: 0.7344 - val_loss: 0.4665 - val_accuracy: 0.7979
# Epoch 7/20
# 104/104 [==============================] - ETA: 0s - loss: 0.5139 - accuracy: 0.7580
# Epoch 7: val_accuracy improved from 0.79786 to 0.81277, saving model to /content/drive/MyDrive/advanced_project/models/lstm_fe_best_model
# 104/104 [==============================] - 9s 84ms/step - loss: 0.5139 - accuracy: 0.7580 - val_loss: 0.4353 - val_accuracy: 0.8128
# Epoch 8/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.4855 - accuracy: 0.7755
# Epoch 8: val_accuracy improved from 0.81277 to 0.82699, saving model to /content/drive/MyDrive/advanced_project/models/lstm_fe_best_model
# 104/104 [==============================] - 7s 67ms/step - loss: 0.4847 - accuracy: 0.7758 - val_loss: 0.4122 - val_accuracy: 0.8270
# Epoch 9/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.4567 - accuracy: 0.7945
# Epoch 9: val_accuracy improved from 0.82699 to 0.83576, saving model to /content/drive/MyDrive/advanced_project/models/lstm_fe_best_model
# 104/104 [==============================] - 8s 82ms/step - loss: 0.4565 - accuracy: 0.7947 - val_loss: 0.3928 - val_accuracy: 0.8358
# Epoch 10/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.4428 - accuracy: 0.8031
# Epoch 10: val_accuracy improved from 0.83576 to 0.84489, saving model to /content/drive/MyDrive/advanced_project/models/lstm_fe_best_model
# 104/104 [==============================] - 7s 67ms/step - loss: 0.4428 - accuracy: 0.8031 - val_loss: 0.3760 - val_accuracy: 0.8449
# Epoch 11/20
# 104/104 [==============================] - ETA: 0s - loss: 0.4277 - accuracy: 0.8099
# Epoch 11: val_accuracy improved from 0.84489 to 0.85225, saving model to /content/drive/MyDrive/advanced_project/models/lstm_fe_best_model
# 104/104 [==============================] - 9s 84ms/step - loss: 0.4277 - accuracy: 0.8099 - val_loss: 0.3622 - val_accuracy: 0.8523
# Epoch 12/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.4117 - accuracy: 0.8166
# Epoch 12: val_accuracy improved from 0.85225 to 0.85769, saving model to /content/drive/MyDrive/advanced_project/models/lstm_fe_best_model
# 104/104 [==============================] - 7s 65ms/step - loss: 0.4115 - accuracy: 0.8167 - val_loss: 0.3499 - val_accuracy: 0.8577
# Epoch 13/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.3975 - accuracy: 0.8240
# Epoch 13: val_accuracy improved from 0.85769 to 0.86068, saving model to /content/drive/MyDrive/advanced_project/models/lstm_fe_best_model
# 104/104 [==============================] - 9s 83ms/step - loss: 0.3975 - accuracy: 0.8239 - val_loss: 0.3380 - val_accuracy: 0.8607
# Epoch 14/20
# 104/104 [==============================] - ETA: 0s - loss: 0.3882 - accuracy: 0.8283
# Epoch 14: val_accuracy improved from 0.86068 to 0.86471, saving model to /content/drive/MyDrive/advanced_project/models/lstm_fe_best_model
# 104/104 [==============================] - 11s 109ms/step - loss: 0.3882 - accuracy: 0.8283 - val_loss: 0.3285 - val_accuracy: 0.8647
# Epoch 15/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.3800 - accuracy: 0.8342
# Epoch 15: val_accuracy improved from 0.86471 to 0.86910, saving model to /content/drive/MyDrive/advanced_project/models/lstm_fe_best_model
# 104/104 [==============================] - 8s 77ms/step - loss: 0.3801 - accuracy: 0.8342 - val_loss: 0.3190 - val_accuracy: 0.8691
# Epoch 16/20
# 104/104 [==============================] - ETA: 0s - loss: 0.3703 - accuracy: 0.8390
# Epoch 16: val_accuracy improved from 0.86910 to 0.87331, saving model to /content/drive/MyDrive/advanced_project/models/lstm_fe_best_model
# 104/104 [==============================] - 8s 74ms/step - loss: 0.3703 - accuracy: 0.8390 - val_loss: 0.3100 - val_accuracy: 0.8733
# Epoch 17/20
# 104/104 [==============================] - ETA: 0s - loss: 0.3593 - accuracy: 0.8450
# Epoch 17: val_accuracy improved from 0.87331 to 0.87559, saving model to /content/drive/MyDrive/advanced_project/models/lstm_fe_best_model
# 104/104 [==============================] - 8s 78ms/step - loss: 0.3593 - accuracy: 0.8450 - val_loss: 0.3041 - val_accuracy: 0.8756
# Epoch 18/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.3492 - accuracy: 0.8489
# Epoch 18: val_accuracy improved from 0.87559 to 0.87928, saving model to /content/drive/MyDrive/advanced_project/models/lstm_fe_best_model
# 104/104 [==============================] - 8s 76ms/step - loss: 0.3495 - accuracy: 0.8488 - val_loss: 0.2983 - val_accuracy: 0.8793
# Epoch 19/20
# 104/104 [==============================] - ETA: 0s - loss: 0.3432 - accuracy: 0.8539
# Epoch 19: val_accuracy improved from 0.87928 to 0.88138, saving model to /content/drive/MyDrive/advanced_project/models/lstm_fe_best_model
# 104/104 [==============================] - 8s 75ms/step - loss: 0.3432 - accuracy: 0.8539 - val_loss: 0.2928 - val_accuracy: 0.8814
# Epoch 20/20
# 104/104 [==============================] - ETA: 0s - loss: 0.3373 - accuracy: 0.8542
# Epoch 20: val_accuracy improved from 0.88138 to 0.88524, saving model to /content/drive/MyDrive/advanced_project/models/lstm_fe_best_model
# 104/104 [==============================] - 8s 73ms/step - loss: 0.3373 - accuracy: 0.8542 - val_loss: 0.2874 - val_accuracy: 0.8852
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# ensure LSTM layer was frozen
final_layer1_weights_values = model_lstm_fe.layers[-1].get_weights()
np.testing.assert_allclose(
    initial_layer1_weights_values[0], final_layer1_weights_values[0]
)
np.testing.assert_allclose(
    initial_layer1_weights_values[1], final_layer1_weights_values[1]
)

# %%
best_lstm_fe = load_model(lstm_fe_checkpoint_path)

score_lstm_fe, acc_lstm_fe = best_lstm_fe.evaluate(X_test_y, y_test_y, verbose=0)
print(f'Test loss for feature extractor LSTM model: {score_lstm_fe:.3f}')
print(f'Test accuracy for feature extractor LSTM model: {acc_lstm_fe:.3f}')
print()
# Out:
# Test loss for feature extractor LSTM model: 0.279
# Test accuracy for feature extractor LSTM model: 0.885

# %%
# Feature extractor approach for BiLSTM
model_bilstm_fe = load_model(bilstm_checkpoint_path)

model_bilstm_fe.layers[-1].trainable = False
initial_layer1_weights_values = model_bilstm_fe.layers[-1].get_weights()

optimizer = Adam(learning_rate=0.001)

model_bilstm_fe.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

bilstm_fe_checkpoint_path = '/content/drive/MyDrive/advanced_project/models/bilstm_fe_best_model'
bilstm_fe_checkpoint = ModelCheckpoint(
    filepath=bilstm_fe_checkpoint_path,
    save_best_only=True,
    monitor='val_accuracy',
    mode='max',
    verbose=1
)

history_bilstm_fe = model_bilstm_fe.fit(
    X_train_y, y_train_y,
    batch_size=256,
    validation_data=(X_val_y, y_val_y),
    epochs=20,
    callbacks=[bilstm_fe_checkpoint]
)

# Print history keys
print(history_bilstm_fe.history.keys())
# Out:
# Epoch 1/20
# 104/104 [==============================] - ETA: 0s - loss: 1.4339 - accuracy: 0.5610
# Epoch 1: val_accuracy improved from -inf to 0.61607, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_fe_best_model
# 104/104 [==============================] - 29s 244ms/step - loss: 1.4339 - accuracy: 0.5610 - val_loss: 0.9595 - val_accuracy: 0.6161
# Epoch 2/20
# 104/104 [==============================] - ETA: 0s - loss: 0.9933 - accuracy: 0.6203
# Epoch 2: val_accuracy improved from 0.61607 to 0.67047, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_fe_best_model
# 104/104 [==============================] - 19s 181ms/step - loss: 0.9933 - accuracy: 0.6203 - val_loss: 0.7187 - val_accuracy: 0.6705
# Epoch 3/20
# 104/104 [==============================] - ETA: 0s - loss: 0.8020 - accuracy: 0.6584
# Epoch 3: val_accuracy improved from 0.67047 to 0.71346, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_fe_best_model
# 104/104 [==============================] - 18s 177ms/step - loss: 0.8020 - accuracy: 0.6584 - val_loss: 0.6162 - val_accuracy: 0.7135
# Epoch 4/20
# 104/104 [==============================] - ETA: 0s - loss: 0.6924 - accuracy: 0.6912
# Epoch 4: val_accuracy improved from 0.71346 to 0.74838, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_fe_best_model
# 104/104 [==============================] - 20s 196ms/step - loss: 0.6924 - accuracy: 0.6912 - val_loss: 0.5522 - val_accuracy: 0.7484
# Epoch 5/20
# 104/104 [==============================] - ETA: 0s - loss: 0.6183 - accuracy: 0.7223
# Epoch 5: val_accuracy improved from 0.74838 to 0.78382, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_fe_best_model
# 104/104 [==============================] - 20s 191ms/step - loss: 0.6183 - accuracy: 0.7223 - val_loss: 0.4924 - val_accuracy: 0.7838
# Epoch 6/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.5445 - accuracy: 0.7537
# Epoch 6: val_accuracy improved from 0.78382 to 0.81155, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_fe_best_model
# 104/104 [==============================] - 22s 215ms/step - loss: 0.5441 - accuracy: 0.7538 - val_loss: 0.4396 - val_accuracy: 0.8115
# Epoch 7/20
# 104/104 [==============================] - ETA: 0s - loss: 0.4978 - accuracy: 0.7815
# Epoch 7: val_accuracy improved from 0.81155 to 0.82523, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_fe_best_model
# 104/104 [==============================] - 20s 193ms/step - loss: 0.4978 - accuracy: 0.7815 - val_loss: 0.4048 - val_accuracy: 0.8252
# Epoch 8/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.4584 - accuracy: 0.7990
# Epoch 8: val_accuracy improved from 0.82523 to 0.83962, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_fe_best_model
# 104/104 [==============================] - 21s 199ms/step - loss: 0.4586 - accuracy: 0.7990 - val_loss: 0.3788 - val_accuracy: 0.8396
# Epoch 9/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.4343 - accuracy: 0.8111
# Epoch 9: val_accuracy improved from 0.83962 to 0.85173, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_fe_best_model
# 104/104 [==============================] - 19s 180ms/step - loss: 0.4344 - accuracy: 0.8109 - val_loss: 0.3574 - val_accuracy: 0.8517
# Epoch 10/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.4134 - accuracy: 0.8215
# Epoch 10: val_accuracy improved from 0.85173 to 0.86155, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_fe_best_model
# 104/104 [==============================] - 24s 234ms/step - loss: 0.4135 - accuracy: 0.8218 - val_loss: 0.3397 - val_accuracy: 0.8616
# Epoch 11/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.3791 - accuracy: 0.8351
# Epoch 11: val_accuracy improved from 0.86155 to 0.87068, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_fe_best_model
# 104/104 [==============================] - 20s 192ms/step - loss: 0.3796 - accuracy: 0.8349 - val_loss: 0.3254 - val_accuracy: 0.8707
# Epoch 12/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.3654 - accuracy: 0.8439
# Epoch 12: val_accuracy improved from 0.87068 to 0.87384, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_fe_best_model
# 104/104 [==============================] - 19s 185ms/step - loss: 0.3652 - accuracy: 0.8441 - val_loss: 0.3134 - val_accuracy: 0.8738
# Epoch 13/20
# 104/104 [==============================] - ETA: 0s - loss: 0.3499 - accuracy: 0.8480
# Epoch 13: val_accuracy improved from 0.87384 to 0.87735, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_fe_best_model
# 104/104 [==============================] - 19s 184ms/step - loss: 0.3499 - accuracy: 0.8480 - val_loss: 0.3047 - val_accuracy: 0.8773
# Epoch 14/20
# 104/104 [==============================] - ETA: 0s - loss: 0.3375 - accuracy: 0.8580
# Epoch 14: val_accuracy improved from 0.87735 to 0.88033, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_fe_best_model
# 104/104 [==============================] - 21s 203ms/step - loss: 0.3375 - accuracy: 0.8580 - val_loss: 0.2970 - val_accuracy: 0.8803
# Epoch 15/20
# 104/104 [==============================] - ETA: 0s - loss: 0.3233 - accuracy: 0.8631
# Epoch 15: val_accuracy improved from 0.88033 to 0.88068, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_fe_best_model
# 104/104 [==============================] - 23s 226ms/step - loss: 0.3233 - accuracy: 0.8631 - val_loss: 0.2903 - val_accuracy: 0.8807
# Epoch 16/20
# 104/104 [==============================] - ETA: 0s - loss: 0.3127 - accuracy: 0.8672
# Epoch 16: val_accuracy improved from 0.88068 to 0.88682, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_fe_best_model
# 104/104 [==============================] - 20s 194ms/step - loss: 0.3127 - accuracy: 0.8672 - val_loss: 0.2834 - val_accuracy: 0.8868
# Epoch 17/20
# 104/104 [==============================] - ETA: 0s - loss: 0.3081 - accuracy: 0.8705
# Epoch 17: val_accuracy improved from 0.88682 to 0.88700, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_fe_best_model
# 104/104 [==============================] - 21s 202ms/step - loss: 0.3081 - accuracy: 0.8705 - val_loss: 0.2793 - val_accuracy: 0.8870
# Epoch 18/20
# 103/104 [============================>.] - ETA: 0s - loss: 0.3022 - accuracy: 0.8725
# Epoch 18: val_accuracy improved from 0.88700 to 0.88752, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_fe_best_model
# 104/104 [==============================] - 18s 179ms/step - loss: 0.3022 - accuracy: 0.8725 - val_loss: 0.2746 - val_accuracy: 0.8875
# Epoch 19/20
# 104/104 [==============================] - ETA: 0s - loss: 0.2922 - accuracy: 0.8768
# Epoch 19: val_accuracy improved from 0.88752 to 0.88893, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_fe_best_model
# 104/104 [==============================] - 26s 253ms/step - loss: 0.2922 - accuracy: 0.8768 - val_loss: 0.2709 - val_accuracy: 0.8889
# Epoch 20/20
# 104/104 [==============================] - ETA: 0s - loss: 0.2879 - accuracy: 0.8789
# Epoch 20: val_accuracy improved from 0.88893 to 0.88945, saving model to /content/drive/MyDrive/advanced_project/models/bilstm_fe_best_model
# 104/104 [==============================] - 20s 197ms/step - loss: 0.2879 - accuracy: 0.8789 - val_loss: 0.2678 - val_accuracy: 0.8895
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
best_bilstm_fe = load_model(bilstm_fe_checkpoint_path)

score_bilstm_fe, acc_bilstm_fe = best_bilstm_fe.evaluate(X_test_y, y_test_y, verbose=0)
print(f'Test loss for feature extractor BiLSTM model: {score_bilstm_fe:.3f}')
print(f'Test accuracy for feature extractor BiLSTM model: {acc_bilstm_fe:.3f}')
print()
# Out:
# Test loss for feature extractor BiLSTM model: 0.267
# Test accuracy for feature extractor BiLSTM model: 0.890
